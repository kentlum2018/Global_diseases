# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import sqlite3

# %%
# found a table containing longitude and latitudes of countries and 
# brought it into pandas

long_lat=pd.read_html("https://developers.google.com/public-data/docs/canonical/countries_csv",skiprows=1)[0]

# renaming columns
long_lat.columns = ['country_code', 'latitude','longitude','name']

# printing dataframe
long_lat.head()
# Out:
#   country_code   latitude  longitude                  name
# 0           AD  42.546245   1.601554               Andorra
# 1           AE  23.424076  53.847818  United Arab Emirates
# 2           AF  33.939110  67.709953           Afghanistan
# 3           AG  17.060816 -61.796428   Antigua and Barbuda
# 4           AI  18.220554 -63.068615              Anguilla

# %%
#  country code 
converting_country_code=pd.read_html("https://www.worldatlas.com/aatlas/ctycodes.htm",skiprows=1)[0]
converting_country_code.columns= ['name','country_code_2','country_code_3','x','y']
converting_country_code=converting_country_code.drop(['x', 'y'], axis=1)
converting_country_code.head()
# Out:
#              name country_code_2 country_code_3
# 0     Afghanistan             AF            AFG
# 1         Albania             AL            ALB
# 2         Algeria             DZ            DZA
# 3  American Samoa             AS            ASM
# 4         Andorra             AD            AND

# %%
merged_col=pd.merge(converting_country_code, long_lat, left_on='country_code_2',right_on="country_code",how="inner")
merged_col.head()
# Out:
#            name_x country_code_2 country_code_3 country_code   latitude  \
# 0     Afghanistan             AF            AFG           AF  33.939110
# 1         Albania             AL            ALB           AL  41.153332
# 2         Algeria             DZ            DZA           DZ  28.033886
# 3  American Samoa             AS            ASM           AS -14.270972
# 4         Andorra             AD            AND           AD  42.546245
#
#     longitude          name_y
# 0   67.709953     Afghanistan
# 1   20.168331         Albania
# 2    1.659626         Algeria
# 3 -170.132217  American Samoa
# 4    1.601554         Andorra

# %%
# cleaning up the pandas dataframe
# dropping cols I dont need
merged_col=merged_col.drop(['name_y','country_code','country_code_2'], axis=1)
merged_col.head()
# Out:
#            name_x country_code_3   latitude   longitude
# 0     Afghanistan            AFG  33.939110   67.709953
# 1         Albania            ALB  41.153332   20.168331
# 2         Algeria            DZA  28.033886    1.659626
# 3  American Samoa            ASM -14.270972 -170.132217
# 4         Andorra            AND  42.546245    1.601554

# %%
# renaming cols
merged_col.columns = ['country','country_code','latitude','longitude']

# %%
merged_col.head()
# Out:
#           country country_code   latitude   longitude
# 0     Afghanistan          AFG  33.939110   67.709953
# 1         Albania          ALB  41.153332   20.168331
# 2         Algeria          DZA  28.033886    1.659626
# 3  American Samoa          ASM -14.270972 -170.132217
# 4         Andorra          AND  42.546245    1.601554

# %%
# Saved the merged cols into a csv
merged_col.to_csv("/Users/muhammadwaliji/Desktop/project_2/country_code.csv")

# %%
# Used the WHO API to get access to how they add the country code and will be 
# merging it with our own table to make sure the data we intend to parse in future from WHO alligns with our 
# merged_col
url = "http://apps.who.int/gho/athena/api/COUNTRY?format=json"
country_r = requests.get(url).json()
country_r
# Out:
# {'copyright': '(c) World Health Organization',
#  'dataset': [],
#  'attribute': [{'label': 'DS', 'display': 'DS'},
#   {'label': 'FIPS', 'display': 'FIPS'},
#   {'label': 'IOC', 'display': 'IOC'},
#   {'label': 'ISO2', 'display': 'ISO2'},
#   {'label': 'ISO', 'display': 'ISO'},
#   {'label': 'ITU', 'display': 'ITU'},
#   {'label': 'MARC', 'display': 'MARC'},
#   {'label': 'WHO', 'display': 'WHO'},
#   {'label': 'WMO', 'display': 'WMO'},
#   {'label': 'GEOMETRY', 'display': 'GEOMETRY'},
#   {'label': 'MORT', 'display': 'MORT'},
#   {'label': 'LAND_AREA_KMSQ_2012', 'display': 'LAND_AREA_KMSQ_2012'},
#   {'label': 'LANGUAGES_EN_2012', 'display': 'LANGUAGES_EN_2012'},
#   {'label': 'WHO_REGION', 'display': 'WHO_REGION'},
#   {'label': 'WHO_REGION_CODE', 'display': 'WHO_REGION_CODE'},
#   {'label': 'WORLD_BANK_INCOME_GROUP', 'display': 'World Bank income group'},
#   {'label': 'WORLD_BANK_INCOME_GROUP_CODE',
#    'display': 'World Bank income group code'},
#   {'label': 'SHORTNAMEES', 'display': 'SHORTNAMEES'},
#   {'label': 'SHORTNAMEFR', 'display': 'SHORTNAMEFR'},
#   {'label': 'WHOLEGALSTATUS', 'display': 'WHOLEGALSTATUS'},
#   {'label': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#    'display': 'World Bank income group GNI reference year'},
#   {'label': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE',
#    'display': 'World Bank income group release date'}],
#  'dimension': [{'label': 'COUNTRY',
#    'display': 'Country',
#    'isMeasure': False,
#    'code': [{'label': 'AFG',
#      'display': 'Afghanistan',
#      'display_sequence': 10,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'WHO_REGION', 'value': 'Eastern Mediterranean'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Low income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LI'},
#       {'category': 'DS', 'value': 'AFG'},
#       {'category': 'FIPS', 'value': 'AF'},
#       {'category': 'IOC', 'value': 'AFG'},
#       {'category': 'ISO2', 'value': 'AF'},
#       {'category': 'ISO', 'value': 'AFG'},
#       {'category': 'ITU', 'value': 'AFG'},
#       {'category': 'MARC', 'value': 'af'},
#       {'category': 'WHO', 'value': 'AFG'},
#       {'category': 'WMO', 'value': 'AF'},
#       {'category': 'GEOMETRY', 'value': 'AFG'},
#       {'category': 'MORT', 'value': '3010'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '652,230'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'Dari, Pashto, Turkic languages, 30 minor languages'},
#       {'category': 'SHORTNAMEES', 'value': 'Afganistan'},
#       {'category': 'SHORTNAMEFR', 'value': 'Afghanistan'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'ALB',
#      'display': 'Albania',
#      'display_sequence': 20,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'WHO_REGION', 'value': 'Europe'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Upper middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EUR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_UMI'},
#       {'category': 'DS', 'value': 'AL'},
#       {'category': 'FIPS', 'value': 'AL'},
#       {'category': 'IOC', 'value': 'ALB'},
#       {'category': 'WMO', 'value': 'AB'},
#       {'category': 'GEOMETRY', 'value': 'ALB'},
#       {'category': 'MORT', 'value': '4005'},
#       {'category': 'ITU', 'value': 'ALB'},
#       {'category': 'MARC', 'value': 'aa'},
#       {'category': 'WHO', 'value': 'ALB'},
#       {'category': 'ISO2', 'value': 'AL'},
#       {'category': 'ISO', 'value': 'ALB'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '27,400'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'Albanian, Greek, Vlach, Romani, Slavic dialects'},
#       {'category': 'SHORTNAMEES', 'value': 'Albania'},
#       {'category': 'SHORTNAMEFR', 'value': 'Albanie'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'DZA',
#      'display': 'Algeria',
#      'display_sequence': 30,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '2,381,740'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'Arabic, French, Berber dialects'},
#       {'category': 'SHORTNAMEES', 'value': 'Argelia'},
#       {'category': 'SHORTNAMEFR', 'value': 'Algérie'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'WHO_REGION', 'value': 'Africa'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Upper middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AFR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_UMI'},
#       {'category': 'DS', 'value': 'DZ'},
#       {'category': 'FIPS', 'value': 'AG'},
#       {'category': 'IOC', 'value': 'ALG'},
#       {'category': 'ISO2', 'value': 'DZ'},
#       {'category': 'ISO', 'value': 'DZA'},
#       {'category': 'ITU', 'value': 'ALG'},
#       {'category': 'MARC', 'value': 'ae'},
#       {'category': 'WHO', 'value': 'ALG'},
#       {'category': 'WMO', 'value': 'AL'},
#       {'category': 'GEOMETRY', 'value': 'DZA'},
#       {'category': 'MORT', 'value': '1010'}]},
#     {'label': 'AND',
#      'display': 'Andorra',
#      'display_sequence': 40,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '470'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'Catalan, French, Castilian, Portuguese'},
#       {'category': 'WHO_REGION', 'value': 'Europe'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EUR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'DS', 'value': 'AND'},
#       {'category': 'FIPS', 'value': 'AN'},
#       {'category': 'IOC', 'value': 'AND'},
#       {'category': 'ISO2', 'value': 'AD'},
#       {'category': 'ISO', 'value': 'AND'},
#       {'category': 'ITU', 'value': 'AND'},
#       {'category': 'MARC', 'value': 'an'},
#       {'category': 'WHO', 'value': 'AND'},
#       {'category': 'GEOMETRY', 'value': 'AND'},
#       {'category': 'MORT', 'value': '4008'},
#       {'category': 'SHORTNAMEES', 'value': 'Andorra'},
#       {'category': 'SHORTNAMEFR', 'value': 'Andorre'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'AGO',
#      'display': 'Angola',
#      'display_sequence': 50,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '1,246,700'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'Portuguese, Bantu, other African languages'},
#       {'category': 'WHO_REGION', 'value': 'Africa'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Lower middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AFR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LMI'},
#       {'category': 'FIPS', 'value': 'AO'},
#       {'category': 'IOC', 'value': 'ANG'},
#       {'category': 'WMO', 'value': 'AN'},
#       {'category': 'GEOMETRY', 'value': 'AGO'},
#       {'category': 'MORT', 'value': '1020'},
#       {'category': 'ITU', 'value': 'AGL'},
#       {'category': 'MARC', 'value': 'ao'},
#       {'category': 'WHO', 'value': 'ANG'},
#       {'category': 'ISO2', 'value': 'AO'},
#       {'category': 'ISO', 'value': 'AGO'},
#       {'category': 'SHORTNAMEES', 'value': 'Angola'},
#       {'category': 'SHORTNAMEFR', 'value': 'Angola'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'ATG',
#      'display': 'Antigua and Barbuda',
#      'display_sequence': 60,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '440'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'English, local dialects'},
#       {'category': 'WHO_REGION', 'value': 'Americas'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'FIPS', 'value': 'AC'},
#       {'category': 'IOC', 'value': 'ANT'},
#       {'category': 'WMO', 'value': 'AT'},
#       {'category': 'GEOMETRY', 'value': 'ATG'},
#       {'category': 'MORT', 'value': '2010'},
#       {'category': 'ITU', 'value': 'ATG'},
#       {'category': 'MARC', 'value': 'aq'},
#       {'category': 'WHO', 'value': 'ANI'},
#       {'category': 'ISO2', 'value': 'AG'},
#       {'category': 'ISO', 'value': 'ATG'},
#       {'category': 'SHORTNAMEES', 'value': 'Antigua y Barbuda'},
#       {'category': 'SHORTNAMEFR', 'value': 'Antigua-et-Barbuda'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'ARG',
#      'display': 'Argentina',
#      'display_sequence': 70,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '2,736,690'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Spanish, others'},
#       {'category': 'WHO_REGION', 'value': 'Americas'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'DS', 'value': 'RA'},
#       {'category': 'FIPS', 'value': 'AR'},
#       {'category': 'IOC', 'value': 'ARG'},
#       {'category': 'WMO', 'value': 'AG'},
#       {'category': 'GEOMETRY', 'value': 'ARG'},
#       {'category': 'MORT', 'value': '2020'},
#       {'category': 'ITU', 'value': 'ARG'},
#       {'category': 'MARC', 'value': 'ag'},
#       {'category': 'WHO', 'value': 'ARG'},
#       {'category': 'ISO2', 'value': 'AR'},
#       {'category': 'ISO', 'value': 'ARG'},
#       {'category': 'SHORTNAMEES', 'value': 'Argentina'},
#       {'category': 'SHORTNAMEFR', 'value': 'Argentine'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'ARM',
#      'display': 'Armenia',
#      'display_sequence': 80,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '28,480'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Armenian'},
#       {'category': 'WHO_REGION', 'value': 'Europe'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Upper middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EUR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_UMI'},
#       {'category': 'DS', 'value': 'AM'},
#       {'category': 'FIPS', 'value': 'AM'},
#       {'category': 'IOC', 'value': 'ARM'},
#       {'category': 'WMO', 'value': 'AY'},
#       {'category': 'GEOMETRY', 'value': 'ARM'},
#       {'category': 'MORT', 'value': '4007'},
#       {'category': 'ITU', 'value': 'ARM'},
#       {'category': 'MARC', 'value': 'ai'},
#       {'category': 'WHO', 'value': 'ARM'},
#       {'category': 'ISO2', 'value': 'AM'},
#       {'category': 'ISO', 'value': 'ARM'},
#       {'category': 'SHORTNAMEES', 'value': 'Armenia'},
#       {'category': 'SHORTNAMEFR', 'value': 'Arménie'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'AUS',
#      'display': 'Australia',
#      'display_sequence': 90,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '7,682,300'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'English'},
#       {'category': 'WHO_REGION', 'value': 'Western Pacific'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'WPR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'DS', 'value': 'AUS'},
#       {'category': 'FIPS', 'value': 'AS'},
#       {'category': 'IOC', 'value': 'AUS'},
#       {'category': 'ISO2', 'value': 'AU'},
#       {'category': 'ISO', 'value': 'AUS'},
#       {'category': 'ITU', 'value': 'AUS'},
#       {'category': 'MARC', 'value': 'at'},
#       {'category': 'WHO', 'value': 'AUS'},
#       {'category': 'WMO', 'value': 'AU'},
#       {'category': 'GEOMETRY', 'value': 'AUS'},
#       {'category': 'MORT', 'value': '5020'},
#       {'category': 'SHORTNAMEES', 'value': 'Australia'},
#       {'category': 'SHORTNAMEFR', 'value': 'Australie'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'AUT',
#      'display': 'Austria',
#      'display_sequence': 100,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '83,871'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'German'},
#       {'category': 'WHO_REGION', 'value': 'Europe'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EUR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'DS', 'value': 'A'},
#       {'category': 'FIPS', 'value': 'AU'},
#       {'category': 'IOC', 'value': 'AUT'},
#       {'category': 'ISO2', 'value': 'AT'},
#       {'category': 'ISO', 'value': 'AUT'},
#       {'category': 'ITU', 'value': 'AUT'},
#       {'category': 'SHORTNAMEES', 'value': 'Austria'},
#       {'category': 'SHORTNAMEFR', 'value': 'Autriche'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'MARC', 'value': 'au'},
#       {'category': 'WHO', 'value': 'AUT'},
#       {'category': 'WMO', 'value': 'OS'},
#       {'category': 'GEOMETRY', 'value': 'AUT'},
#       {'category': 'MORT', 'value': '4010'}]},
#     {'label': 'AZE',
#      'display': 'Azerbaijan',
#      'display_sequence': 110,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '82,450'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Azerbaijani, others'},
#       {'category': 'WHO_REGION', 'value': 'Europe'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Upper middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EUR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_UMI'},
#       {'category': 'SHORTNAMEES', 'value': 'Azerbaijan'},
#       {'category': 'DS', 'value': 'AZ'},
#       {'category': 'FIPS', 'value': 'AJ'},
#       {'category': 'IOC', 'value': 'AZE'},
#       {'category': 'ISO2', 'value': 'AZ'},
#       {'category': 'ISO', 'value': 'AZE'},
#       {'category': 'ITU', 'value': 'AZE'},
#       {'category': 'MARC', 'value': 'aj'},
#       {'category': 'WHO', 'value': 'AZE'},
#       {'category': 'WMO', 'value': 'AJ'},
#       {'category': 'GEOMETRY', 'value': 'AZE'},
#       {'category': 'MORT', 'value': '4012'},
#       {'category': 'SHORTNAMEFR', 'value': 'Azerbaïdjan'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'BHS',
#      'display': 'Bahamas',
#      'display_sequence': 120,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '10,010'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'English, Creole'},
#       {'category': 'WHO_REGION', 'value': 'Americas'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'DS', 'value': 'BS'},
#       {'category': 'FIPS', 'value': 'BF'},
#       {'category': 'IOC', 'value': 'BAH'},
#       {'category': 'ISO2', 'value': 'BS'},
#       {'category': 'ISO', 'value': 'BHS'},
#       {'category': 'ITU', 'value': 'BAH'},
#       {'category': 'MARC', 'value': 'bf'},
#       {'category': 'WHO', 'value': 'BAH'},
#       {'category': 'WMO', 'value': 'BA'},
#       {'category': 'GEOMETRY', 'value': 'BHS'},
#       {'category': 'MORT', 'value': '2030'},
#       {'category': 'SHORTNAMEES', 'value': 'Bahamas'},
#       {'category': 'SHORTNAMEFR', 'value': 'Bahamas'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'BHR',
#      'display': 'Bahrain',
#      'display_sequence': 130,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '760'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'Arabic, English, Farsi, Urdu'},
#       {'category': 'WHO_REGION', 'value': 'Eastern Mediterranean'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'DS', 'value': 'BRN'},
#       {'category': 'FIPS', 'value': 'BA'},
#       {'category': 'IOC', 'value': 'BRN'},
#       {'category': 'WMO', 'value': 'BN'},
#       {'category': 'GEOMETRY', 'value': 'BHR'},
#       {'category': 'MORT', 'value': '3020'},
#       {'category': 'ITU', 'value': 'BHR'},
#       {'category': 'MARC', 'value': 'ba'},
#       {'category': 'WHO', 'value': 'BAA'},
#       {'category': 'ISO2', 'value': 'BH'},
#       {'category': 'ISO', 'value': 'BHR'},
#       {'category': 'SHORTNAMEES', 'value': 'Bahrein'},
#       {'category': 'SHORTNAMEFR', 'value': 'Bahreïn'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'BGD',
#      'display': 'Bangladesh',
#      'display_sequence': 140,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '130,170'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Bangla, English'},
#       {'category': 'WHO_REGION', 'value': 'South-East Asia'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Lower middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'SEAR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LMI'},
#       {'category': 'DS', 'value': 'BD'},
#       {'category': 'FIPS', 'value': 'BG'},
#       {'category': 'IOC', 'value': 'BAN'},
#       {'category': 'ISO2', 'value': 'BD'},
#       {'category': 'ISO', 'value': 'BGD'},
#       {'category': 'ITU', 'value': 'BGD'},
#       {'category': 'MARC', 'value': 'bg'},
#       {'category': 'WHO', 'value': 'BAN'},
#       {'category': 'WMO', 'value': 'BW'},
#       {'category': 'GEOMETRY', 'value': 'BGD'},
#       {'category': 'MORT', 'value': '3025'},
#       {'category': 'SHORTNAMEES', 'value': 'Bangladesh'},
#       {'category': 'SHORTNAMEFR', 'value': 'Bangladesh'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'BRB',
#      'display': 'Barbados',
#      'display_sequence': 150,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '430'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'English'},
#       {'category': 'WHO_REGION', 'value': 'Americas'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'DS', 'value': 'BDS'},
#       {'category': 'FIPS', 'value': 'BB'},
#       {'category': 'IOC', 'value': 'BAR'},
#       {'category': 'ISO2', 'value': 'BB'},
#       {'category': 'ISO', 'value': 'BRB'},
#       {'category': 'ITU', 'value': 'BRB'},
#       {'category': 'MARC', 'value': 'bb'},
#       {'category': 'WHO', 'value': 'BAR'},
#       {'category': 'WMO', 'value': 'BR'},
#       {'category': 'GEOMETRY', 'value': 'BRB'},
#       {'category': 'MORT', 'value': '2040'},
#       {'category': 'SHORTNAMEES', 'value': 'Barbados'},
#       {'category': 'SHORTNAMEFR', 'value': 'Barbade'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'BLR',
#      'display': 'Belarus',
#      'display_sequence': 160,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '202,900'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Belarusian, Russian'},
#       {'category': 'WHO_REGION', 'value': 'Europe'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Upper middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EUR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_UMI'},
#       {'category': 'DS', 'value': 'BY'},
#       {'category': 'FIPS', 'value': 'BO'},
#       {'category': 'IOC', 'value': 'BLR'},
#       {'category': 'ISO2', 'value': 'BY'},
#       {'category': 'ISO', 'value': 'BLR'},
#       {'category': 'ITU', 'value': 'BLR'},
#       {'category': 'MARC', 'value': 'bw'},
#       {'category': 'WHO', 'value': 'BLR'},
#       {'category': 'WMO', 'value': 'BY'},
#       {'category': 'GEOMETRY', 'value': 'BLR'},
#       {'category': 'MORT', 'value': '4018'},
#       {'category': 'SHORTNAMEES', 'value': 'Belarus'},
#       {'category': 'SHORTNAMEFR', 'value': 'Bélarus'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'BEL',
#      'display': 'Belgium',
#      'display_sequence': 170,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '30,280'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Dutch, French, German'},
#       {'category': 'WHO_REGION', 'value': 'Europe'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EUR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'DS', 'value': 'B'},
#       {'category': 'FIPS', 'value': 'BE'},
#       {'category': 'IOC', 'value': 'BEL'},
#       {'category': 'ISO2', 'value': 'BE'},
#       {'category': 'ISO', 'value': 'BEL'},
#       {'category': 'ITU', 'value': 'BEL'},
#       {'category': 'MARC', 'value': 'be'},
#       {'category': 'WHO', 'value': 'BEL'},
#       {'category': 'WMO', 'value': 'BX'},
#       {'category': 'GEOMETRY', 'value': 'BEL'},
#       {'category': 'MORT', 'value': '4020'},
#       {'category': 'SHORTNAMEES', 'value': 'Belgica'},
#       {'category': 'SHORTNAMEFR', 'value': 'Belgique'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'BLZ',
#      'display': 'Belize',
#      'display_sequence': 180,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '22,810'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'Spanish, Creole, Mayan dialects, English'},
#       {'category': 'WHO_REGION', 'value': 'Americas'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Upper middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_UMI'},
#       {'category': 'DS', 'value': 'BZ'},
#       {'category': 'FIPS', 'value': 'BH'},
#       {'category': 'IOC', 'value': 'BIZ'},
#       {'category': 'ISO2', 'value': 'BZ'},
#       {'category': 'ISO', 'value': 'BLZ'},
#       {'category': 'ITU', 'value': 'BLZ'},
#       {'category': 'MARC', 'value': 'bh'},
#       {'category': 'WHO', 'value': 'BLZ'},
#       {'category': 'WMO', 'value': 'BH'},
#       {'category': 'GEOMETRY', 'value': 'BLZ'},
#       {'category': 'MORT', 'value': '2045'},
#       {'category': 'SHORTNAMEES', 'value': 'Belice'},
#       {'category': 'SHORTNAMEFR', 'value': 'Belize'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'}]},
#     {'label': 'BEN',
#      'display': 'Benin',
#      'display_sequence': 190,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '112,760'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'French, Fon, Yoruba, tribal languages'},
#       {'category': 'WHO_REGION', 'value': 'Africa'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Low income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AFR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LI'},
#       {'category': 'DS', 'value': 'DY'},
#       {'category': 'FIPS', 'value': 'BN'},
#       {'category': 'IOC', 'value': 'BEN'},
#       {'category': 'ISO2', 'value': 'BJ'},
#       {'category': 'ISO', 'value': 'BEN'},
#       {'category': 'ITU', 'value': 'BEN'},
#       {'category': 'MARC', 'value': 'dm'},
#       {'category': 'WHO', 'value': 'BEN'},
#       {'category': 'WMO', 'value': 'BJ'},
#       {'category': 'SHORTNAMEES', 'value': 'Benin'},
#       {'category': 'SHORTNAMEFR', 'value': 'Bénin'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'GEOMETRY', 'value': 'BEN'},
#       {'category': 'MORT', 'value': '1025'}]},
#     {'label': 'BTN',
#      'display': 'Bhutan',
#      'display_sequence': 200,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '38,394'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'Sharchhopka, Dzongkha, Lhotshamkha, others'},
#       {'category': 'WHO_REGION', 'value': 'South-East Asia'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Lower middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'SEAR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LMI'},
#       {'category': 'SHORTNAMEES', 'value': 'Bhutan'},
#       {'category': 'SHORTNAMEFR', 'value': 'Bhoutan'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'FIPS', 'value': 'BT'},
#       {'category': 'IOC', 'value': 'BHU'},
#       {'category': 'GEOMETRY', 'value': 'BTN'},
#       {'category': 'MORT', 'value': '3027'},
#       {'category': 'ITU', 'value': 'BTN'},
#       {'category': 'MARC', 'value': 'bt'},
#       {'category': 'WHO', 'value': 'BHU'},
#       {'category': 'ISO2', 'value': 'BT'},
#       {'category': 'ISO', 'value': 'BTN'}]},
#     {'label': 'BOL',
#      'display': 'Bolivia (Plurinational State of)',
#      'display_sequence': 210,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '1,083,300'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Spanish, Quechua, Aymara'},
#       {'category': 'WHO_REGION', 'value': 'Americas'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Lower middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LMI'},
#       {'category': 'SHORTNAMEES',
#        'value': 'Bolivia (Estado Plurinacional de)'},
#       {'category': 'SHORTNAMEFR', 'value': 'Bolivie (État plurinational de)'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'DS', 'value': 'BOL'},
#       {'category': 'FIPS', 'value': 'BL'},
#       {'category': 'IOC', 'value': 'BOL'},
#       {'category': 'ISO2', 'value': 'BO'},
#       {'category': 'ISO', 'value': 'BOL'},
#       {'category': 'ITU', 'value': 'BOL'},
#       {'category': 'MARC', 'value': 'bo'},
#       {'category': 'WHO', 'value': 'BOL'},
#       {'category': 'WMO', 'value': 'BO'},
#       {'category': 'GEOMETRY', 'value': 'BOL'},
#       {'category': 'MORT', 'value': '2060'}]},
#     {'label': 'BIH',
#      'display': 'Bosnia and Herzegovina',
#      'display_sequence': 220,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '51,000'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Bosnian, Croatian, Serbian'},
#       {'category': 'WHO_REGION', 'value': 'Europe'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Upper middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EUR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_UMI'},
#       {'category': 'SHORTNAMEES', 'value': 'Bosnia y Herzegovina'},
#       {'category': 'SHORTNAMEFR', 'value': 'Bosnie-Herzégovine'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'DS', 'value': 'BIH'},
#       {'category': 'FIPS', 'value': 'BK'},
#       {'category': 'IOC', 'value': 'BIH'},
#       {'category': 'WMO', 'value': 'BG'},
#       {'category': 'GEOMETRY', 'value': 'BIH'},
#       {'category': 'MORT', 'value': '4025'},
#       {'category': 'ITU', 'value': 'BIH'},
#       {'category': 'MARC', 'value': 'bn'},
#       {'category': 'WHO', 'value': 'BIH'},
#       {'category': 'ISO2', 'value': 'BA'},
#       {'category': 'ISO', 'value': 'BIH'}]},
#     {'label': 'BWA',
#      'display': 'Botswana',
#      'display_sequence': 230,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '566,730'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Setswana, Kalanga, English'},
#       {'category': 'WHO_REGION', 'value': 'Africa'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Upper middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AFR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_UMI'},
#       {'category': 'SHORTNAMEES', 'value': 'Botswana'},
#       {'category': 'SHORTNAMEFR', 'value': 'Botswana'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'DS', 'value': 'BW'},
#       {'category': 'FIPS', 'value': 'BC'},
#       {'category': 'IOC', 'value': 'BOT'},
#       {'category': 'WMO', 'value': 'BC'},
#       {'category': 'GEOMETRY', 'value': 'BWA'},
#       {'category': 'MORT', 'value': '1030'},
#       {'category': 'ITU', 'value': 'BOT'},
#       {'category': 'MARC', 'value': 'bs'},
#       {'category': 'WHO', 'value': 'BOT'},
#       {'category': 'ISO2', 'value': 'BW'},
#       {'category': 'ISO', 'value': 'BWA'}]},
#     {'label': 'BRA',
#      'display': 'Brazil',
#      'display_sequence': 240,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '8,459,420'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Portuguese'},
#       {'category': 'WHO_REGION', 'value': 'Americas'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Upper middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_UMI'},
#       {'category': 'SHORTNAMEES', 'value': 'Brasil'},
#       {'category': 'SHORTNAMEFR', 'value': 'Brésil'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'DS', 'value': 'BR'},
#       {'category': 'FIPS', 'value': 'BR'},
#       {'category': 'IOC', 'value': 'BRA'},
#       {'category': 'ISO2', 'value': 'BR'},
#       {'category': 'ISO', 'value': 'BRA'},
#       {'category': 'ITU', 'value': 'B'},
#       {'category': 'MARC', 'value': 'bl'},
#       {'category': 'WHO', 'value': 'BRA'},
#       {'category': 'WMO', 'value': 'BZ'},
#       {'category': 'GEOMETRY', 'value': 'BRA'},
#       {'category': 'MORT', 'value': '2070'}]},
#     {'label': 'BRN',
#      'display': 'Brunei Darussalam',
#      'display_sequence': 250,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '5270'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'English, Malay, Chinese'},
#       {'category': 'WHO_REGION', 'value': 'Western Pacific'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'WPR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'SHORTNAMEES', 'value': 'Brunei Darussalam'},
#       {'category': 'SHORTNAMEFR', 'value': 'Brunéi Darussalam'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'DS', 'value': 'BRU'},
#       {'category': 'FIPS', 'value': 'BX'},
#       {'category': 'IOC', 'value': 'BRU'},
#       {'category': 'ISO2', 'value': 'BN'},
#       {'category': 'ISO', 'value': 'BRN'},
#       {'category': 'ITU', 'value': 'BRU'},
#       {'category': 'MARC', 'value': 'bx'},
#       {'category': 'WHO', 'value': 'BRU'},
#       {'category': 'WMO', 'value': 'BD'},
#       {'category': 'GEOMETRY', 'value': 'BRN'},
#       {'category': 'MORT', 'value': '3030'}]},
#     {'label': 'BGR',
#      'display': 'Bulgaria',
#      'display_sequence': 260,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '108,610'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Bulgarian, others'},
#       {'category': 'WHO_REGION', 'value': 'Europe'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Upper middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EUR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_UMI'},
#       {'category': 'SHORTNAMEES', 'value': 'Bulgaria'},
#       {'category': 'SHORTNAMEFR', 'value': 'Bulgarie'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'DS', 'value': 'BG'},
#       {'category': 'FIPS', 'value': 'BU'},
#       {'category': 'IOC', 'value': 'BUL'},
#       {'category': 'ISO2', 'value': 'BG'},
#       {'category': 'ISO', 'value': 'BGR'},
#       {'category': 'ITU', 'value': 'BUL'},
#       {'category': 'MARC', 'value': 'bu'},
#       {'category': 'WHO', 'value': 'BUL'},
#       {'category': 'WMO', 'value': 'BU'},
#       {'category': 'GEOMETRY', 'value': 'BGR'},
#       {'category': 'MORT', 'value': '4030'}]},
#     {'label': 'BFA',
#      'display': 'Burkina Faso',
#      'display_sequence': 270,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '273,600'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'French, native African languages'},
#       {'category': 'WHO_REGION', 'value': 'Africa'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Low income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AFR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LI'},
#       {'category': 'SHORTNAMEES', 'value': 'Burkina Faso'},
#       {'category': 'SHORTNAMEFR', 'value': 'Burkina Faso'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'DS', 'value': 'BF'},
#       {'category': 'FIPS', 'value': 'UV'},
#       {'category': 'IOC', 'value': 'BUR'},
#       {'category': 'WMO', 'value': 'HV'},
#       {'category': 'GEOMETRY', 'value': 'BFA'},
#       {'category': 'MORT', 'value': '1035'},
#       {'category': 'ITU', 'value': 'BFA'},
#       {'category': 'MARC', 'value': 'uv'},
#       {'category': 'WHO', 'value': 'BFA'},
#       {'category': 'ISO2', 'value': 'BF'},
#       {'category': 'ISO', 'value': 'BFA'}]},
#     {'label': 'BDI',
#      'display': 'Burundi',
#      'display_sequence': 280,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '25,680'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Kirundi, French, Swahili'},
#       {'category': 'WHO_REGION', 'value': 'Africa'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Low income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AFR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LI'},
#       {'category': 'SHORTNAMEES', 'value': 'Burundi'},
#       {'category': 'SHORTNAMEFR', 'value': 'Burundi'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'DS', 'value': 'RU'},
#       {'category': 'FIPS', 'value': 'BY'},
#       {'category': 'IOC', 'value': 'BDI'},
#       {'category': 'WMO', 'value': 'BI'},
#       {'category': 'GEOMETRY', 'value': 'BDI'},
#       {'category': 'MORT', 'value': '1040'},
#       {'category': 'ITU', 'value': 'BDI'},
#       {'category': 'MARC', 'value': 'bd'},
#       {'category': 'WHO', 'value': 'BUU'},
#       {'category': 'ISO2', 'value': 'BI'},
#       {'category': 'ISO', 'value': 'BDI'}]},
#     {'label': 'KHM',
#      'display': 'Cambodia',
#      'display_sequence': 310,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '176,520'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Khmer, French, English'},
#       {'category': 'SHORTNAMEES', 'value': 'Camboya'},
#       {'category': 'SHORTNAMEFR', 'value': 'Cambodge'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'WHO_REGION', 'value': 'Western Pacific'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Lower middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'WPR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LMI'},
#       {'category': 'DS', 'value': 'K'},
#       {'category': 'FIPS', 'value': 'CB'},
#       {'category': 'IOC', 'value': 'CAM'},
#       {'category': 'ISO2', 'value': 'KH'},
#       {'category': 'ISO', 'value': 'KHM'},
#       {'category': 'ITU', 'value': 'CBG'},
#       {'category': 'MARC', 'value': 'cb'},
#       {'category': 'WHO', 'value': 'CAM'},
#       {'category': 'WMO', 'value': 'KP'},
#       {'category': 'GEOMETRY', 'value': 'KHM'},
#       {'category': 'MORT', 'value': '3050'}]},
#     {'label': 'CMR',
#      'display': 'Cameroon',
#      'display_sequence': 320,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '472,710'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'French, English, 24 African language groups'},
#       {'category': 'SHORTNAMEES', 'value': 'Camerun'},
#       {'category': 'SHORTNAMEFR', 'value': 'Cameroun'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'WHO_REGION', 'value': 'Africa'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Lower middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AFR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LMI'},
#       {'category': 'DS', 'value': 'CAM'},
#       {'category': 'FIPS', 'value': 'CM'},
#       {'category': 'IOC', 'value': 'CMR'},
#       {'category': 'WMO', 'value': 'CM'},
#       {'category': 'GEOMETRY', 'value': 'CMR'},
#       {'category': 'MORT', 'value': '1045'},
#       {'category': 'ITU', 'value': 'CME'},
#       {'category': 'MARC', 'value': 'cm'},
#       {'category': 'WHO', 'value': 'CAE'},
#       {'category': 'ISO2', 'value': 'CM'},
#       {'category': 'ISO', 'value': 'CMR'}]},
#     {'label': 'CAN',
#      'display': 'Canada',
#      'display_sequence': 330,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '9,093,510'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'English, French, others'},
#       {'category': 'WHO_REGION', 'value': 'Americas'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'SHORTNAMEES', 'value': 'Canada'},
#       {'category': 'SHORTNAMEFR', 'value': 'Canada'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'DS', 'value': 'CDN'},
#       {'category': 'FIPS', 'value': 'CA'},
#       {'category': 'IOC', 'value': 'CAN'},
#       {'category': 'ISO2', 'value': 'CA'},
#       {'category': 'ISO', 'value': 'CAN'},
#       {'category': 'ITU', 'value': 'CAN'},
#       {'category': 'MARC', 'value': 'xxc'},
#       {'category': 'WHO', 'value': 'CAN'},
#       {'category': 'WMO', 'value': 'CN'},
#       {'category': 'GEOMETRY', 'value': 'CAN'},
#       {'category': 'MORT', 'value': '2090'}]},
#     {'label': 'CPV',
#      'display': 'Cabo Verde',
#      'display_sequence': 300,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '4,030'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Portuguese, Crioulo'},
#       {'category': 'SHORTNAMEES', 'value': 'Cabo Verde'},
#       {'category': 'SHORTNAMEFR', 'value': 'Cabo Verde'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'WHO_REGION', 'value': 'Africa'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Lower middle income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AFR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LMI'},
#       {'category': 'FIPS', 'value': 'CV'},
#       {'category': 'IOC', 'value': 'CPV'},
#       {'category': 'ISO2', 'value': 'CV'},
#       {'category': 'ISO', 'value': 'CPV'},
#       {'category': 'ITU', 'value': 'CPV'},
#       {'category': 'MARC', 'value': 'cv'},
#       {'category': 'WHO', 'value': 'CAV'},
#       {'category': 'WMO', 'value': 'CV'},
#       {'category': 'GEOMETRY', 'value': 'CPV'},
#       {'category': 'MORT', 'value': '1060'}]},
#     {'label': 'CAF',
#      'display': 'Central African Republic',
#      'display_sequence': 340,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '622,980'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'Sango, French, tribal languages'},
#       {'category': 'WHO_REGION', 'value': 'Africa'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Low income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AFR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LI'},
#       {'category': 'SHORTNAMEES', 'value': 'Republica Centroafricana'},
#       {'category': 'SHORTNAMEFR', 'value': 'République centrafricaine'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'DS', 'value': 'RCA'},
#       {'category': 'FIPS', 'value': 'CT'},
#       {'category': 'IOC', 'value': 'CAF'},
#       {'category': 'ISO2', 'value': 'CF'},
#       {'category': 'ISO', 'value': 'CAF'},
#       {'category': 'ITU', 'value': 'CAF'},
#       {'category': 'MARC', 'value': 'cx'},
#       {'category': 'WHO', 'value': 'CAF'},
#       {'category': 'WMO', 'value': 'CE'},
#       {'category': 'GEOMETRY', 'value': 'CAF'},
#       {'category': 'MORT', 'value': '1070'}]},
#     {'label': 'TCD',
#      'display': 'Chad',
#      'display_sequence': 350,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '1,259,200'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'French, Arabic, Sara, more than 120 different languages and dialects'},
#       {'category': 'SHORTNAMEES', 'value': 'Chad (el)'},
#       {'category': 'SHORTNAMEFR', 'value': 'Tchad'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'WHO_REGION', 'value': 'Africa'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Low income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AFR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LI'},
#       {'category': 'DS', 'value': 'TCH'},
#       {'category': 'FIPS', 'value': 'CD'},
#       {'category': 'IOC', 'value': 'CHA'},
#       {'category': 'ISO2', 'value': 'TD'},
#       {'category': 'ISO', 'value': 'TCD'},
#       {'category': 'ITU', 'value': 'TCD'},
#       {'category': 'MARC', 'value': 'cd'},
#       {'category': 'WHO', 'value': 'CHA'},
#       {'category': 'WMO', 'value': 'CD'},
#       {'category': 'GEOMETRY', 'value': 'TCD'},
#       {'category': 'MORT', 'value': '1080'}]},
#     {'label': 'CHL',
#      'display': 'Chile',
#      'display_sequence': 360,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '743,532'},
#       {'category': 'LANGUAGES_EN_2012', 'value': 'Spanish, others'},
#       {'category': 'WHO_REGION', 'value': 'Americas'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'SHORTNAMEES', 'value': 'Chile'},
#       {'category': 'SHORTNAMEFR', 'value': 'Chili'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'DS', 'value': 'RCH'},
#       {'category': 'FIPS', 'value': 'CI'},
#       {'category': 'IOC', 'value': 'CHI'},
#       {'category': 'WMO', 'value': 'CH'},
#       {'category': 'GEOMETRY', 'value': 'CHL'},
#       {'category': 'MORT', 'value': '2120'},
#       {'category': 'ITU', 'value': 'CHL'},
#       {'category': 'MARC', 'value': 'cl'},
#       {'category': 'WHO', 'value': 'CHI'},
#       {'category': 'ISO2', 'value': 'CL'},
#       {'category': 'ISO', 'value': 'CHL'}]},
#     {'label': 'CHN',
#      'display': 'China',
#      'display_sequence': 370,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'LAND_AREA_KMSQ_2012', 'value': '9,327,489'},
#       {'category': 'LANGUAGES_EN_2012',
#        'value': 'Mandarin, Cantonese, others'},
#       {'category': 'SHORTNAMEES', 'value': 'China'},
#       {'category': 'SHORTNAMEFR', 'value': 'Chine'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'WHO_REGION', 'value': 'Western Pacific'},
# ...
#       {'category': 'ISO', 'value': 'MAC'},
#       {'category': 'GEOMETRY', 'value': 'MAC'},
#       {'category': 'MORT', 'value': '3220'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'XX4',
#      'display': 'Ryu Kyu Islands',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'ISO', 'value': 'XX4'},
#       {'category': 'GEOMETRY', 'value': 'XX4'},
#       {'category': 'MORT', 'value': '3330'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'XX5',
#      'display': 'Czechoslovakia, Former',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'ISO', 'value': 'XX5'},
#       {'category': 'GEOMETRY', 'value': 'XX5'},
#       {'category': 'MORT', 'value': '4040'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'XX6',
#      'display': 'Germany, Former Democratic Republic',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'GEOMETRY', 'value': 'XX6'},
#       {'category': 'MORT', 'value': '4090'},
#       {'category': 'ISO', 'value': 'XX6'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'XX7',
#      'display': 'Germany, Former Federal Republic',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'ISO', 'value': 'XX7'},
#       {'category': 'GEOMETRY', 'value': 'XX7'},
#       {'category': 'MORT', 'value': '4100'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'XX8',
#      'display': 'Germany, West Berlin',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'GEOMETRY', 'value': 'XX8'},
#       {'category': 'MORT', 'value': '4120'},
#       {'category': 'ISO', 'value': 'XX8'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'XX9',
#      'display': 'USSR, Former',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'ISO', 'value': 'XX9'},
#       {'category': 'GEOMETRY', 'value': 'XX9'},
#       {'category': 'MORT', 'value': '4304'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'GUF',
#      'display': 'French Guiana',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'GEOMETRY', 'value': 'GUF'},
#       {'category': 'MORT', 'value': '2210'},
#       {'category': 'ISO', 'value': 'GUF'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'X10',
#      'display': 'United Kingdom, England and Wales',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'ISO', 'value': 'X10'},
#       {'category': 'GEOMETRY', 'value': 'X10'},
#       {'category': 'MORT', 'value': '4310'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'X11',
#      'display': 'United Kingdom, Northern Ireland',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'GEOMETRY', 'value': 'X11'},
#       {'category': 'MORT', 'value': '4320'},
#       {'category': 'ISO', 'value': 'X11'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'X12',
#      'display': 'United Kingdom, Scotland',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'ISO', 'value': 'X12'},
#       {'category': 'GEOMETRY', 'value': 'X12'},
#       {'category': 'MORT', 'value': '4330'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'X13',
#      'display': 'Yugoslavia, Former',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'ISO', 'value': 'X13'},
#       {'category': 'GEOMETRY', 'value': 'X13'},
#       {'category': 'MORT', 'value': '4340'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'SCG',
#      'display': 'Serbia and Montenegro, Former',
#      'display_sequence': 1530,
#      'url': '',
#      'attr': [{'category': 'GEOMETRY', 'value': 'SCG'},
#       {'category': 'MORT', 'value': '4350'},
#       {'category': 'ISO2', 'value': 'CS'},
#       {'category': 'ISO', 'value': 'SCG'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'PSE',
#      'display': 'West Bank and Gaza Strip',
#      'display_sequence': 1935,
#      'url': '',
#      'attr': [{'category': 'ISO', 'value': 'PSE'},
#       {'category': 'GEOMETRY', 'value': 'PSE'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Lower middle income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LMI'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'NA',
#      'display': 'NA',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'GEOMETRY', 'value': 'NA'},
#       {'category': 'ISO', 'value': 'NA'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'GUM',
#      'display': 'Guam',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'ISO', 'value': 'GUM'},
#       {'category': 'GEOMETRY', 'value': 'GUM'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'MYT',
#      'display': 'Mayotte',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'ISO', 'value': 'MYT'},
#       {'category': 'GEOMETRY', 'value': 'MYT'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'PYF',
#      'display': 'French Polynesia',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'GEOMETRY', 'value': 'PYF'},
#       {'category': 'ISO', 'value': 'PYF'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'FRO',
#      'display': 'Faroe Islands',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'ISO', 'value': 'FRO'},
#       {'category': 'GEOMETRY', 'value': 'FRO'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'GRL',
#      'display': 'Greenland',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'ISO', 'value': 'GRL'},
#       {'category': 'GEOMETRY', 'value': 'GRL'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'SHN',
#      'display': 'Saint Helena',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'GEOMETRY', 'value': 'SHN'},
#       {'category': 'ISO', 'value': 'SHN'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'NCL',
#      'display': 'New Caledonia',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'ISO', 'value': 'NCL'},
#       {'category': 'GEOMETRY', 'value': 'NCL'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'ASM',
#      'display': 'American Samoa',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP',
#        'value': 'Upper middle income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_UMI'},
#       {'category': 'ISO', 'value': 'ASM'},
#       {'category': 'GEOMETRY', 'value': 'ASM'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'TKL',
#      'display': 'Tokelau',
#      'display_sequence': 1760,
#      'url': '',
#      'attr': [{'category': 'WHOLEGALSTATUS', 'value': 'A'},
#       {'category': 'GEOMETRY', 'value': 'TKL'},
#       {'category': 'ISO', 'value': 'TKL'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'MNP',
#      'display': 'Northern Mariana Islands',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'ISO', 'value': 'MNP'},
#       {'category': 'GEOMETRY', 'value': 'MNP'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'GIB',
#      'display': 'Gibraltar',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'},
#       {'category': 'GEOMETRY', 'value': 'GIB'},
#       {'category': 'ISO', 'value': 'GIB'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'}]},
#     {'label': 'LIE',
#      'display': 'Liechtenstein',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'GEOMETRY', 'value': 'LIE'},
#       {'category': 'ISO', 'value': 'LIE'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'PCN',
#      'display': 'Pitcairn Island',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'GEOMETRY', 'value': 'PCN'},
#       {'category': 'ISO', 'value': 'PCN'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'WLF',
#      'display': 'Wallis and Futuna Islands',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'ISO', 'value': 'WLF'},
#       {'category': 'GEOMETRY', 'value': 'WLF'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'NFK',
#      'display': 'Norfolk Island',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'GEOMETRY', 'value': 'NFK'},
#       {'category': 'ISO', 'value': 'NFK'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'BES',
#      'display': 'Bonaire, Saint Eustatius and Saba',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'ISO', 'value': 'BES'},
#       {'category': 'GEOMETRY', 'value': 'BES'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'CUW',
#      'display': 'Curaçao',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'ISO', 'value': 'CUW'},
#       {'category': 'GEOMETRY', 'value': 'CUW'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'SXM',
#      'display': 'Sint Maarten (Dutch part)',
#      'display_sequence': 0,
#      'url': '',
#      'attr': [{'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'High income'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_HI'},
#       {'category': 'ISO', 'value': 'SXM'},
#       {'category': 'GEOMETRY', 'value': 'SXM'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'SSD',
#      'display': 'South Sudan',
#      'display_sequence': 1620,
#      'url': '',
#      'attr': [{'category': 'SHORTNAMEES', 'value': 'Sudan del Sur'},
#       {'category': 'SHORTNAMEFR', 'value': 'Soudan du Sud'},
#       {'category': 'WHOLEGALSTATUS', 'value': 'M'},
#       {'category': 'WHO_REGION', 'value': 'Africa'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Low income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'AFR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LI'},
#       {'category': 'GEOMETRY', 'value': 'SSD'},
#       {'category': 'ISO', 'value': 'SSD'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE', 'value': '2018'}]},
#     {'label': 'SDF',
#      'display': 'Sudan (former)',
#      'display_sequence': 1655,
#      'url': '',
#      'attr': [{'category': 'WHO_REGION', 'value': 'Eastern Mediterranean'},
#       {'category': 'WORLD_BANK_INCOME_GROUP', 'value': 'Lower-middle-income'},
#       {'category': 'WHO_REGION_CODE', 'value': 'EMR'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_CODE', 'value': 'WB_LMI'},
#       {'category': 'ISO', 'value': 'SDF'},
#       {'category': 'GEOMETRY', 'value': 'SDN'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_GNI_REFERENCE_YEAR',
#        'value': '2017'},
#       {'category': 'WORLD_BANK_INCOME_GROUP_RELEASE_DATE',
#        'value': '2018'}]}]}],
#  'fact': []}

# %%
# checking to see what needs to be added into the country_r to output the country_code 

country_r['dimension'][0]['code'][0]['label']
# Out:
# 'AFG'

# %%
# Creating a list of all the country_codes I can get from the WHO website

who_country_list=[]

country_code=country_r['dimension'][0]['code']

for country in country_code:
    who_country_list.append(country["label"])

# %%
# converting the list into a dataframe and renaming the col. I did this 
# so I can merge this dataframe with the one we made earlier to make sure all the who countries are in the mergel_col

who_df=pd.DataFrame(who_country_list)
who_df.columns=["who_country"]
who_df.head()
# Out:
#   who_country
# 0         AFG
# 1         ALB
# 2         DZA
# 3         AND
# 4         AGO

# %%
# merging the two data frames together on country code. this output 226 
# countries which is sufficent for our data set
who_and_others=pd.merge(merged_col, who_df, left_on='country_code',right_on="who_country",how="inner")
who_and_others.head()
# Out:
#           country country_code   latitude   longitude who_country
# 0     Afghanistan          AFG  33.939110   67.709953         AFG
# 1         Albania          ALB  41.153332   20.168331         ALB
# 2         Algeria          DZA  28.033886    1.659626         DZA
# 3  American Samoa          ASM -14.270972 -170.132217         ASM
# 4         Andorra          AND  42.546245    1.601554         AND

# %%
who_and_others=who_and_others.drop(['who_country'], axis=1)

# %%
who_and_others.head(1)
# Out:
#        country country_code  latitude  longitude
# 0  Afghanistan          AFG  33.93911  67.709953

# %%
who_and_others.to_csv("/Users/muhammadwaliji/Desktop/project_2/who_inc_country_code.csv")

# %%
# Option 1 use pd.to_sql
# Option 2 write insert statements in the code

# %% [markdown]
# ## Option 1: Use pd.to_sql

# %%
sqlite_filename = '/Users/muhammadwaliji/Desktop/project_2/who_country_code_mhw.sqlite'

# %%
# Need to have a database with many tables one of which is this one
# but having either a table named this or a database named this but
# not both


# sqlite_filename = '/Users/muhammadwaliji/Desktop/project_2/who_country_code_mhw.db'

# %%
conn = sqlite3.connect(sqlite_filename)

who_and_others.to_sql("long_lat_frompandas", conn, if_exists="replace")

# conn.close()

# %%
cur = conn.cursor()
cur.execute("SELECT * FROM long_lat_frompandas")
rows = cur.fetchall()
for row in rows:
    print(row)
# Out:
# (0, 'Afghanistan', 'AFG', 33.93911, 67.709953)
# (1, 'Albania', 'ALB', 41.153332, 20.168331)
# (2, 'Algeria', 'DZA', 28.033886, 1.6596259999999998)
# (3, 'American Samoa', 'ASM', -14.270972, -170.132217)
# (4, 'Andorra', 'AND', 42.546245, 1.6015540000000001)
# (5, 'Angola', 'AGO', -11.202691999999999, 17.873887)
# (6, 'Anguilla', 'AIA', 18.220554, -63.068615)
# (7, 'Antigua and Barbuda', 'ATG', 17.060816, -61.796428000000006)
# (8, 'Argentina', 'ARG', -38.416097, -63.616671999999994)
# (9, 'Armenia', 'ARM', 40.069099, 45.038189)
# (10, 'Aruba', 'ABW', 12.52111, -69.968338)
# (11, 'Australia', 'AUS', -25.274398, 133.775136)
# (12, 'Austria', 'AUT', 47.516231, 14.550072)
# (13, 'Azerbaijan', 'AZE', 40.143105, 47.576927000000005)
# (14, 'Bahamas', 'BHS', 25.03428, -77.39628)
# (15, 'Bahrain', 'BHR', 25.930414000000003, 50.637772)
# (16, 'Bangladesh', 'BGD', 23.684994, 90.35633100000001)
# (17, 'Barbados', 'BRB', 13.193887, -59.543198)
# (18, 'Belarus', 'BLR', 53.709807, 27.953389)
# (19, 'Belgium', 'BEL', 50.503887, 4.469936)
# (20, 'Belize', 'BLZ', 17.189877, -88.49765)
# (21, 'Benin', 'BEN', 9.30769, 2.315834)
# (22, 'Bermuda', 'BMU', 32.321384, -64.75737)
# (23, 'Bhutan', 'BTN', 27.514162, 90.433601)
# (24, 'Bolivia', 'BOL', -16.290154, -63.588653)
# (25, 'Bosnia and Herzegovina', 'BIH', 43.915886, 17.679076000000002)
# (26, 'Botswana', 'BWA', -22.328474, 24.684866)
# (27, 'Brazil', 'BRA', -14.235004, -51.92528)
# (28, 'Brunei Darussalam', 'BRN', 4.535277, 114.72766899999999)
# (29, 'Bulgaria', 'BGR', 42.733883, 25.48583)
# (30, 'Burkina Faso', 'BFA', 12.238333, -1.561593)
# (31, 'Burundi', 'BDI', -3.3730559999999996, 29.918885999999997)
# (32, 'Cambodia', 'KHM', 12.565679, 104.990963)
# (33, 'Cameroon', 'CMR', 7.369722, 12.354722)
# (34, 'Canada', 'CAN', 56.130366, -106.34677099999999)
# (35, 'Cape Verde', 'CPV', 16.002082, -24.013197)
# (36, 'Cayman Islands', 'CYM', 19.513469, -80.566956)
# (37, 'Central African Republic', 'CAF', 6.611111, 20.939444)
# (38, 'Chad', 'TCD', 15.454166, 18.732207)
# (39, 'Chile', 'CHL', -35.675146999999996, -71.542969)
# (40, 'China', 'CHN', 35.86166, 104.195397)
# (41, 'Colombia', 'COL', 4.570868, -74.297333)
# (42, 'Comoros', 'COM', -11.875001, 43.872219)
# (43, 'Congo', 'COG', -0.228021, 15.827658999999999)
# (44, 'Democratic Republic of the Congo', 'COD', -4.038333000000001, 21.758664000000003)
# (45, 'Cook Islands', 'COK', -21.236735999999997, -159.777671)
# (46, 'Costa Rica', 'CRI', 9.748917, -83.753428)
# (47, 'Croatia', 'HRV', 45.1, 15.2)
# (48, 'Cuba', 'CUB', 21.521757, -77.78116700000001)
# (49, 'Cyprus', 'CYP', 35.126413, 33.429859)
# (50, 'Czech Republic', 'CZE', 49.817492, 15.472961999999999)
# (51, "Cote d'Ivoire", 'CIV', 7.539989, -5.54708)
# (52, 'Denmark', 'DNK', 56.26392, 9.501785)
# (53, 'Djibouti', 'DJI', 11.825138, 42.590275)
# (54, 'Dominica', 'DMA', 15.414999, -61.370976)
# (55, 'Dominican Republic', 'DOM', 18.735692999999998, -70.162651)
# (56, 'Ecuador', 'ECU', -1.8312389999999998, -78.183406)
# (57, 'Egypt', 'EGY', 26.820553000000004, 30.802497999999996)
# (58, 'El Salvador', 'SLV', 13.794185, -88.89653)
# (59, 'Equatorial Guinea', 'GNQ', 1.6508009999999997, 10.267895)
# (60, 'Eritrea', 'ERI', 15.179383999999999, 39.782334000000006)
# (61, 'Estonia', 'EST', 58.595271999999994, 25.013607)
# (62, 'Ethiopia', 'ETH', 9.145, 40.489672999999996)
# (63, 'Falkland Islands (Malvinas)', 'FLK', -51.796253, -59.523613)
# (64, 'Faroe Islands', 'FRO', 61.892635, -6.9118059999999995)
# (65, 'Fiji', 'FJI', -16.578193, 179.414413)
# (66, 'Finland', 'FIN', 61.92411, 25.748151)
# (67, 'France', 'FRA', 46.227638, 2.213749)
# (68, 'French Guiana', 'GUF', 3.9338889999999997, -53.125781999999994)
# (69, 'French Polynesia', 'PYF', -17.679742, -149.40684299999998)
# (70, 'Gabon', 'GAB', -0.803689, 11.609444)
# (71, 'Gambia', 'GMB', 13.443182, -15.310139000000001)
# (72, 'Georgia', 'GEO', 42.315407, 43.356891999999995)
# (73, 'Germany', 'DEU', 51.165690999999995, 10.451526)
# (74, 'Ghana', 'GHA', 7.946527000000001, -1.0231940000000002)
# (75, 'Gibraltar', 'GIB', 36.137741, -5.345374)
# (76, 'Greece', 'GRC', 39.074208, 21.824312)
# (77, 'Greenland', 'GRL', 71.706936, -42.604303)
# (78, 'Grenada', 'GRD', 12.262775999999999, -61.604170999999994)
# (79, 'Guadeloupe', 'GLP', 16.995971, -62.067641)
# (80, 'Guam', 'GUM', 13.444304, 144.793731)
# (81, 'Guatemala', 'GTM', 15.783470999999999, -90.23075899999999)
# (82, 'Guinea', 'GIN', 9.945587, -9.696645)
# (83, 'Guinea-Bissau', 'GNB', 11.803749, -15.180413)
# (84, 'Guyana', 'GUY', 4.860416000000001, -58.93018000000001)
# (85, 'Haiti', 'HTI', 18.971187, -72.28521500000001)
# (86, 'Honduras', 'HND', 15.199998999999998, -86.241905)
# (87, 'Hong Kong', 'HKG', 22.396428, 114.10949699999999)
# (88, 'Hungary', 'HUN', 47.162494, 19.503304)
# (89, 'Iceland', 'ISL', 64.96305100000001, -19.020835)
# (90, 'India', 'IND', 20.593684, 78.96288)
# (91, 'Indonesia', 'IDN', -0.789275, 113.921327)
# (92, 'Iran, Islamic Republic of', 'IRN', 32.427908, 53.68804599999999)
# (93, 'Iraq', 'IRQ', 33.223191, 43.679291)
# (94, 'Ireland', 'IRL', 53.41291, -8.243889999999999)
# (95, 'Israel', 'ISR', 31.046051000000002, 34.851612)
# (96, 'Italy', 'ITA', 41.87194, 12.56738)
# (97, 'Jamaica', 'JAM', 18.109581, -77.297508)
# (98, 'Japan', 'JPN', 36.204824, 138.252924)
# (99, 'Jordan', 'JOR', 30.585164000000002, 36.238414)
# (100, 'Kazakhstan', 'KAZ', 48.019573, 66.923684)
# (101, 'Kenya', 'KEN', -0.023559, 37.906193)
# (102, 'Kiribati', 'KIR', -3.3704169999999998, -168.734039)
# (103, "Korea, Democratic People's Republic of", 'PRK', 40.339852, 127.510093)
# (104, 'Korea, Republic of', 'KOR', 35.907757000000004, 127.766922)
# (105, 'Kuwait', 'KWT', 29.311659999999996, 47.481766)
# (106, 'Kyrgyzstan', 'KGZ', 41.20438, 74.766098)
# (107, "Lao People's Democratic Republic", 'LAO', 19.856270000000002, 102.495496)
# (108, 'Latvia', 'LVA', 56.879635, 24.603189)
# (109, 'Lebanon', 'LBN', 33.854721000000005, 35.862285)
# (110, 'Lesotho', 'LSO', -29.609988, 28.233608)
# (111, 'Liberia', 'LBR', 6.4280550000000005, -9.429499)
# (112, 'Libya', 'LBY', 26.3351, 17.228331)
# (113, 'Liechtenstein', 'LIE', 47.166000000000004, 9.555373)
# (114, 'Lithuania', 'LTU', 55.169438, 23.881275)
# (115, 'Luxembourg', 'LUX', 49.815273, 6.129583)
# (116, 'Macao', 'MAC', 22.198745000000002, 113.543873)
# (117, 'Macedonia, the Former Yugoslav Republic of', 'MKD', 41.608635, 21.745275)
# (118, 'Madagascar', 'MDG', -18.766947000000002, 46.869107)
# (119, 'Malawi', 'MWI', -13.254307999999998, 34.301525)
# (120, 'Malaysia', 'MYS', 4.210483999999999, 101.97576600000001)
# (121, 'Maldives', 'MDV', 3.202778, 73.22068)
# (122, 'Mali', 'MLI', 17.570692, -3.9961660000000006)
# (123, 'Malta', 'MLT', 35.937496, 14.375416)
# (124, 'Marshall Islands', 'MHL', 7.131474000000001, 171.184478)
# (125, 'Martinique', 'MTQ', 14.641528, -61.024174)
# (126, 'Mauritania', 'MRT', 21.00789, -10.940835)
# (127, 'Mauritius', 'MUS', -20.348404000000002, 57.552152)
# (128, 'Mayotte', 'MYT', -12.8275, 45.166244)
# (129, 'Mexico', 'MEX', 23.634501, -102.552784)
# (130, 'Micronesia, Federated States of', 'FSM', 7.425553999999999, 150.550812)
# (131, 'Moldova, Republic of', 'MDA', 47.411631, 28.369884999999996)
# (132, 'Monaco', 'MCO', 43.750298, 7.412841)
# (133, 'Mongolia', 'MNG', 46.862496, 103.84665600000001)
# (134, 'Montenegro', 'MNE', 42.708678000000006, 19.37439)
# (135, 'Montserrat', 'MSR', 16.742498, -62.187366000000004)
# (136, 'Morocco', 'MAR', 31.791702, -7.09262)
# (137, 'Mozambique', 'MOZ', -18.665695, 35.529562)
# (138, 'Myanmar', 'MMR', 21.913965, 95.956223)
# (139, 'Namibia', 'NAM', -22.957639999999998, 18.49041)
# (140, 'Nauru', 'NRU', -0.522778, 166.931503)
# (141, 'Nepal', 'NPL', 28.394857000000002, 84.12400799999999)
# (142, 'Netherlands', 'NLD', 52.132633, 5.291266)
# (143, 'New Caledonia', 'NCL', -20.904304999999997, 165.618042)
# (144, 'New Zealand', 'NZL', -40.900557, 174.88597099999998)
# (145, 'Nicaragua', 'NIC', 12.865416, -85.207229)
# (146, 'Niger', 'NER', 17.607789, 8.081666)
# (147, 'Nigeria', 'NGA', 9.081999, 8.675277000000001)
# (148, 'Niue', 'NIU', -19.054445, -169.867233)
# (149, 'Norfolk Island', 'NFK', -29.040834999999998, 167.954712)
# (150, 'Northern Mariana Islands', 'MNP', 17.33083, 145.38468999999998)
# (151, 'Norway', 'NOR', 60.472024, 8.468946)
# (152, 'Oman', 'OMN', 21.512583, 55.923255000000005)
# (153, 'Pakistan', 'PAK', 30.375321000000003, 69.345116)
# (154, 'Palau', 'PLW', 7.51498, 134.58252)
# (155, 'Palestine, State of', 'PSE', 31.952162, 35.233154)
# (156, 'Panama', 'PAN', 8.537981, -80.782127)
# (157, 'Papua New Guinea', 'PNG', -6.314993, 143.95555)
# (158, 'Paraguay', 'PRY', -23.442503, -58.44383199999999)
# (159, 'Peru', 'PER', -9.189967, -75.015152)
# (160, 'Philippines', 'PHL', 12.879721, 121.77401699999999)
# (161, 'Pitcairn', 'PCN', -24.703615, -127.43930800000001)
# (162, 'Poland', 'POL', 51.919438, 19.145135999999997)
# (163, 'Portugal', 'PRT', 39.399871999999995, -8.224454)
# (164, 'Puerto Rico', 'PRI', 18.220833, -66.590149)
# (165, 'Qatar', 'QAT', 25.354826, 51.183884)
# (166, 'Romania', 'ROU', 45.943160999999996, 24.96676)
# (167, 'Russian Federation', 'RUS', 61.52401, 105.31875600000001)
# (168, 'Rwanda', 'RWA', -1.940278, 29.873888)
# (169, 'Reunion', 'REU', -21.115141, 55.536384)
# (170, 'Saint Helena', 'SHN', -24.143473999999998, -10.030696)
# (171, 'Saint Kitts and Nevis', 'KNA', 17.357822, -62.782998)
# (172, 'Saint Lucia', 'LCA', 13.909444, -60.97889300000001)
# (173, 'Saint Pierre and Miquelon', 'SPM', 46.941936, -56.27111)
# (174, 'Saint Vincent and the Grenadines', 'VCT', 12.984305, -61.287228000000006)
# (175, 'Samoa', 'WSM', -13.759029, -172.10462900000002)
# (176, 'San Marino', 'SMR', 43.94236, 12.457777)
# (177, 'Sao Tome and Principe', 'STP', 0.18636, 6.613081)
# (178, 'Saudi Arabia', 'SAU', 23.885942, 45.079162)
# (179, 'Senegal', 'SEN', 14.497401000000002, -14.452361999999999)
# (180, 'Serbia', 'SRB', 44.016521000000004, 21.005859)
# (181, 'Seychelles', 'SYC', -4.679574, 55.491977)
# (182, 'Sierra Leone', 'SLE', 8.460555000000001, -11.779889)
# (183, 'Singapore', 'SGP', 1.352083, 103.819836)
# (184, 'Slovakia', 'SVK', 48.669026, 19.699023999999998)
# (185, 'Slovenia', 'SVN', 46.151241, 14.995463)
# (186, 'Solomon Islands', 'SLB', -9.645710000000001, 160.156194)
# (187, 'Somalia', 'SOM', 5.152149, 46.199616)
# (188, 'South Africa', 'ZAF', -30.559482, 22.937506)
# (189, 'Spain', 'ESP', 40.463667, -3.7492199999999998)
# (190, 'Sri Lanka', 'LKA', 7.873054, 80.77179699999999)
# (191, 'Sudan', 'SDN', 12.862807, 30.217636)
# (192, 'Suriname', 'SUR', 3.9193050000000005, -56.02778299999999)
# (193, 'Swaziland', 'SWZ', -26.522503000000004, 31.465866)
# (194, 'Sweden', 'SWE', 60.128161, 18.643501)
# (195, 'Switzerland', 'CHE', 46.818188, 8.227511999999999)
# (196, 'Syrian Arab Republic', 'SYR', 34.802075, 38.996815000000005)
# (197, 'Tajikistan', 'TJK', 38.861034000000004, 71.276093)
# (198, 'United Republic of Tanzania', 'TZA', -6.369028, 34.888822)
# (199, 'Thailand', 'THA', 15.870032, 100.992541)
# (200, 'Timor-Leste', 'TLS', -8.874217, 125.727539)
# (201, 'Togo', 'TGO', 8.619543, 0.824782)
# (202, 'Tokelau', 'TKL', -8.967363, -171.855881)
# (203, 'Tonga', 'TON', -21.178986, -175.198242)
# (204, 'Trinidad and Tobago', 'TTO', 10.691803, -61.222503)
# (205, 'Tunisia', 'TUN', 33.886917, 9.537499)
# (206, 'Turkey', 'TUR', 38.963745, 35.243322)
# (207, 'Turkmenistan', 'TKM', 38.969719, 59.556278000000006)
# (208, 'Turks and Caicos Islands', 'TCA', 21.694025, -71.797928)
# (209, 'Tuvalu', 'TUV', -7.109535, 177.64933)
# (210, 'Uganda', 'UGA', 1.373333, 32.290275)
# (211, 'Ukraine', 'UKR', 48.379433, 31.16558)
# (212, 'United Arab Emirates', 'ARE', 23.424076, 53.847818000000004)
# (213, 'United Kingdom', 'GBR', 55.378051, -3.435973)
# (214, 'United States', 'USA', 37.09024, -95.712891)
# (215, 'Uruguay', 'URY', -32.522779, -55.765834999999996)
# (216, 'Uzbekistan', 'UZB', 41.377491, 64.585262)
# (217, 'Vanuatu', 'VUT', -15.376706, 166.959158)
# (218, 'Venezuela', 'VEN', 6.42375, -66.58973)
# (219, 'Viet Nam', 'VNM', 14.058323999999999, 108.277199)
# (220, 'British Virgin Islands', 'VGB', 18.420695000000002, -64.63996800000001)
# (221, 'US Virgin Islands', 'VIR', 18.335765, -64.896335)
# (222, 'Wallis and Futuna', 'WLF', -13.768752, -177.156097)
# (223, 'Yemen', 'YEM', 15.552726999999999, 48.516388)
# (224, 'Zambia', 'ZMB', -13.133897, 27.849332)
# (225, 'Zimbabwe', 'ZWE', -19.015438, 29.154857)

# %%
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-29-d4424d4927ea> in <module>()
# ----> 1 cur.close()
#       2 conn.close()
#
# ProgrammingError: Cannot operate on a closed database.

# %% [markdown]
# ## Option 2: Write insert statements in the code

# %%
import sqlite3

# %%
sqlite_filename = '/Users/muhammadwaliji/Desktop/project_2/who_country_code_mhw.sqlite'

# %%
conn = sqlite3.connect(sqlite_filename)
cur = conn.cursor()

# %%
cur.execute("DROP TABLE IF EXISTS long_lat;")

# %%
cur.execute("""
CREATE TABLE long_lat (
    id INTEGER PRIMARY KEY,
    country VARCHAR(255),
    country_code VARCHAR(255),
    latitude FLOAT,
    longitude FLOAT
)
""")

# %%
# closing cursor and connection commits the changes you have made to the database. If you do not close
# the changes may not have saved in the sqlite file. 
# Another reason to close also is that sqlite can only run in one place at one time so you have to close the 
# connection here in order to run it on the terminal
conn.commit()
cur.close()
conn.close()

# %%
conn = sqlite3.connect(sqlite_filename)
cur = conn.cursor()

# %%
# for idx, row in who_and_others.iterrows():
#     cur.execute(f"""
#         INSERT INTO long_lat(id, country, country_code, latitude, longitude) VALUES 
#         ({idx},'{row.country}','{row.country_code}', {row.latitude}, {row.longitude})
#     """)
# conn.commit()

# %%
for idx, row in who_and_others.iterrows():
    cur.execute(f"""
        INSERT INTO long_lat(id, country, country_code, latitude, longitude) VALUES 
        (?, ?, ?, ?, ?)
    """,
               [idx,
               row.country,
               row.country_code,
               row.latitude,
               row.longitude])
conn.commit()

# %%
cur.close()
conn.close()

# %%
pd.options.display.max_rows = 999

# %% [markdown]
# ## SQL ALCHEMY STARTS HERE

# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy.orm import Session

from sqlalchemy.ext.automap import automap_base

# %%
engine=create_engine("sqlite:///Users/muhammadwaliji/Desktop/project_2/who_country_code.sqlite")
Base = automap_base()

# %%
session = Session(engine)

# %%
Base.prepare(engine, reflect=True)

# %%
class who_country_code(Base):
    __tablename__ = 'long_lat'
    id = Column(Integer, primary_key=True)
    country = Column(String)
    country_code = Column(String)
    latitude = Column(Float)
    longitude = Column(Float)

# %%
Base.metadata.tables

# %%
Base.metadata.create_all(engine)

# %%
session = Session(engine)

# %%
# URLS used
# 1. table of countries and long lats
# https://developers.google.com/public-data/docs/canonical/countries_csv
# 2. Make data frame with 3 and 2 letter country code
# https://www.worldatlas.com/aatlas/ctycodes.htm
