# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from pymongo import MongoClient

# %% [markdown]
# ## Extracting the longitude Latitude table

# %%
# found a table containing longitude and latitudes of countries and 
# brought it into pandas

long_lat=pd.read_html("https://developers.google.com/public-data/docs/canonical/countries_csv",skiprows=1)[0]

# renaming columns
long_lat.columns = ['country_code', 'latitude','longitude','name']

# printing dataframe
long_lat.head()
# Out:
#   country_code   latitude  longitude                  name
# 0           AE  23.424076  53.847818  United Arab Emirates
# 1           AF  33.939110  67.709953           Afghanistan
# 2           AG  17.060816 -61.796428   Antigua and Barbuda
# 3           AI  18.220554 -63.068615              Anguilla
# 4           AL  41.153332  20.168331               Albania

# %%
#  country code 
converting_country_code=pd.read_html("https://www.worldatlas.com/aatlas/ctycodes.htm",skiprows=1)[0]
converting_country_code.columns= ['name','country_code_2','country_code_3','x','y']
converting_country_code=converting_country_code.drop(['x', 'y'], axis=1)
converting_country_code.head()
# Out:
#              name country_code_2 country_code_3
# 0     Afghanistan             AF            AFG
# 1         Albania             AL            ALB
# 2         Algeria             DZ            DZA
# 3  American Samoa             AS            ASM
# 4         Andorra             AD            AND

# %%
merged_col=pd.merge(converting_country_code, long_lat, left_on='country_code_2',right_on="country_code",how="inner")
merged_col.head()
# Out:
#            name_x country_code_2 country_code_3 country_code   latitude  \
# 0     Afghanistan             AF            AFG           AF  33.939110
# 1         Albania             AL            ALB           AL  41.153332
# 2         Algeria             DZ            DZA           DZ  28.033886
# 3  American Samoa             AS            ASM           AS -14.270972
# 4          Angola             AO            AGO           AO -11.202692
#
#     longitude          name_y
# 0   67.709953     Afghanistan
# 1   20.168331         Albania
# 2    1.659626         Algeria
# 3 -170.132217  American Samoa
# 4   17.873887          Angola

# %%
# cleaning up the pandas dataframe
# dropping cols I dont need
merged_col=merged_col.drop(['name_y','country_code','country_code_2'], axis=1)
merged_col.head()
# Out:
#            name_x country_code_3   latitude   longitude
# 0     Afghanistan            AFG  33.939110   67.709953
# 1         Albania            ALB  41.153332   20.168331
# 2         Algeria            DZA  28.033886    1.659626
# 3  American Samoa            ASM -14.270972 -170.132217
# 4          Angola            AGO -11.202692   17.873887

# %%
# renaming cols
merged_col.columns = ['country','country_code','latitude','longitude']

# %%
merged_col.head()
# Out:
#           country country_code   latitude   longitude
# 0     Afghanistan          AFG  33.939110   67.709953
# 1         Albania          ALB  41.153332   20.168331
# 2         Algeria          DZA  28.033886    1.659626
# 3  American Samoa          ASM -14.270972 -170.132217
# 4          Angola          AGO -11.202692   17.873887

# %%
# Accessing WHO country list to narrow lat/longs to relevent names
country_r = requests.get("http://apps.who.int/gho/athena/api/COUNTRY?format=json").json()

# %%
# checking to see what needs to be added into the country_r to output the country_code 

country_r['dimension'][0]['code'][0]['label']
# Out:
# 'AFG'

# %%
# Creating a list of all the country_codes I can get from the WHO website

who_country_list=[]

country_code=country_r['dimension'][0]['code']

for country in country_code:
    who_country_list.append(country["label"])

# %%
# converting the list into a dataframe and renaming the col. I did this 
# so I can merge this dataframe with the one we made earlier to make sure all the who countries are in the mergel_col
who_df=pd.DataFrame(who_country_list)
who_df.columns=["who_country"]
who_df.head()
# Out:
#   who_country
# 0         AFG
# 1         ALB
# 2         DZA
# 3         AND
# 4         AGO

# %%
# merging the two data frames together on country code. this output 226 
# countries which is sufficent for our data set
who_and_others=pd.merge(merged_col, who_df, left_on='country_code',right_on="who_country",how="inner")
who_and_others.head()
# Out:
#           country country_code   latitude   longitude who_country
# 0     Afghanistan          AFG  33.939110   67.709953         AFG
# 1         Albania          ALB  41.153332   20.168331         ALB
# 2         Algeria          DZA  28.033886    1.659626         DZA
# 3  American Samoa          ASM -14.270972 -170.132217         ASM
# 4          Angola          AGO -11.202692   17.873887         AGO

# %%
who_and_others=who_and_others.drop(['who_country'], axis=1)

# %%
who_and_others.head(1)
# who_and_others.shape
# Out:
#        country country_code  latitude  longitude
# 0  Afghanistan          AFG  33.93911  67.709953

# %% [markdown]
# ## Extracting the Disease data using API

# %%
## diseases calls

url_before = "http://apps.who.int/gho/athena/data/GHO/"
url_after = "?format=html&filter=COUNTRY:*"
malaria_code = "WHS3_48"
yel_fev_code = "WHS3_50"
leprosy_code = "WHS3_45"
code_list = ["WHS3_48", "WHS3_50", "WHS3_45"]
disease_list = ["Malaria", "Yellow Fever", "Leprosy"]

# %%
malaria_url = url_before + malaria_code + url_after
yel_fev_url = url_before + yel_fev_code + url_after
leprosy_url = url_before + leprosy_code + url_after

# %%
mal_raw = pd.read_html(malaria_url)[0]

# %%
yel_raw = pd.read_html(yel_fev_url)[0]

# %%
lep_raw = pd.read_html(leprosy_url)[0]

# %%
# display data to observe
display(mal_raw.head())
display(yel_raw.head())
display(lep_raw.head())
# Out:
#                                             GHO PUBLISHSTATE  YEAR  \
# 0  Malaria - number of reported confirmed cases    Published  2011
# 1  Malaria - number of reported confirmed cases    Published  2005
# 2  Malaria - number of reported confirmed cases    Published  2017
# 3  Malaria - number of reported confirmed cases    Published  2014
# 4  Malaria - number of reported confirmed cases    Published  2008
#
#             REGION                   COUNTRY  DISPLAY VALUE  NUMERIC VALUE  \
# 0  Western Pacific                  Cambodia          57423        57423.0
# 1           Africa                     Gabon          70644        70644.0
# 2           Africa  Central African Republic         383309       383309.0
# 3         Americas                Costa Rica              0            0.0
# 4           Africa                     Congo         117291       117291.0
#
#    LOW RANGE  HIGH RANGE  Comment
# 0        NaN         NaN      NaN
# 1        NaN         NaN      NaN
# 2        NaN         NaN      NaN
# 3        NaN         NaN      NaN
# 4        NaN         NaN      NaN
#                                        GHO PUBLISHSTATE  YEAR    REGION  \
# 0  Yellow fever - number of reported cases    Published  2008    Europe
# 1  Yellow fever - number of reported cases    Published  2004    Africa
# 2  Yellow fever - number of reported cases    Published  2016  Americas
# 3  Yellow fever - number of reported cases    Published  2015    Africa
# 4  Yellow fever - number of reported cases    Published  2004    Africa
#
#   WORLDBANKINCOMEGROUP        COUNTRY  DISPLAY VALUE  NUMERIC VALUE  \
# 0          High-income         France              0            0.0
# 1  Lower-middle-income         Zambia              0            0.0
# 2  Lower-middle-income      Guatemala              0            0.0
# 3  Lower-middle-income          Ghana              0            0.0
# 4           Low-income  Guinea-Bissau              0            0.0
#
#    LOW RANGE  HIGH RANGE  Comment
# 0        NaN         NaN      NaN
# 1        NaN         NaN      NaN
# 2        NaN         NaN      NaN
# 3        NaN         NaN      NaN
# 4        NaN         NaN      NaN
#                            GHO PUBLISHSTATE  YEAR REGION        COUNTRY  \
# 0  Number of new leprosy cases    Published  2006    NaN       Kiribati
# 1  Number of new leprosy cases    Published  2008    NaN           Iraq
# 2  Number of new leprosy cases    Published  2007    NaN       Eswatini
# 3  Number of new leprosy cases    Published  2014    NaN  Guinea-Bissau
# 4  Number of new leprosy cases    Published  2012    NaN         Brazil
#
#   DISPLAY VALUE  NUMERIC VALUE  LOW RANGE  HIGH RANGE  Comment
# 0            41           41.0        NaN         NaN      NaN
# 1             0            0.0        NaN         NaN      NaN
# 2       No data            NaN        NaN         NaN      NaN
# 3       No data            NaN        NaN         NaN      NaN
# 4         33303        33303.0        NaN         NaN      NaN

# %%
mal_cols = mal_raw.loc[:, ['YEAR', 'COUNTRY', 'NUMERIC VALUE']].copy('deep')
mal_cols['DISEASE'] = 'Malaria'

# %%
yel_cols = yel_raw.loc[:, ['YEAR', 'COUNTRY', 'NUMERIC VALUE']].copy('deep')
yel_cols['DISEASE'] = 'Yellow Fever'

# %%
lep_cols = lep_raw.loc[:, ['YEAR', 'COUNTRY', 'NUMERIC VALUE']].copy('deep')
lep_cols['DISEASE'] = 'Leprosy'

# %%
# observe changes to data
display(mal_cols.head())
display(yel_cols.head())
display(lep_cols.head())
# Out:
#    YEAR                   COUNTRY  NUMERIC VALUE  DISEASE
# 0  2011                  Cambodia        57423.0  Malaria
# 1  2005                     Gabon        70644.0  Malaria
# 2  2017  Central African Republic       383309.0  Malaria
# 3  2014                Costa Rica            0.0  Malaria
# 4  2008                     Congo       117291.0  Malaria
#    YEAR        COUNTRY  NUMERIC VALUE       DISEASE
# 0  2008         France            0.0  Yellow Fever
# 1  2004         Zambia            0.0  Yellow Fever
# 2  2016      Guatemala            0.0  Yellow Fever
# 3  2015          Ghana            0.0  Yellow Fever
# 4  2004  Guinea-Bissau            0.0  Yellow Fever
#    YEAR        COUNTRY  NUMERIC VALUE  DISEASE
# 0  2006       Kiribati           41.0  Leprosy
# 1  2008           Iraq            0.0  Leprosy
# 2  2007       Eswatini            NaN  Leprosy
# 3  2014  Guinea-Bissau            NaN  Leprosy
# 4  2012         Brazil        33303.0  Leprosy

# %%
dfs = [mal_cols, yel_cols, lep_cols]

# %%
disease_df = pd.concat(dfs)

# %%
disease_df.columns = ['year', 'country', 'instances', 'disease']
disease_df.head()
# Out:
#    year                   country  instances  disease
# 0  2011                  Cambodia    57423.0  Malaria
# 1  2005                     Gabon    70644.0  Malaria
# 2  2017  Central African Republic   383309.0  Malaria
# 3  2014                Costa Rica        0.0  Malaria
# 4  2008                     Congo   117291.0  Malaria

# %%
disease_df["instances"]=disease_df["instances"].fillna(0)
disease_df.count()
# Out:
# year         6828
# country      6828
# disease      6828
# instances    6828
# dtype: int64

# %% [markdown]
# # Temperature data from NOAA

# %%
temp_data_url="https://www.ncdc.noaa.gov/cag/global/time-series/globe/land_ocean/12/9/1980-2019"

# %%
temp_data_df=pd.read_html(temp_data_url)[0]
temp_data_df=temp_data_df.drop(['Rank'], axis=1)

# %%
temp_data_df.head(6)
# Out:
#    Year Anomaly(1901-2000 Base Period)
# 0  1980                         0.29°C
# 1  1981                         0.30°C
# 2  1982                         0.19°C
# 3  1983                         0.33°C
# 4  1984                         0.22°C
# 5  1985                         0.10°C

# %%
temp_data_df.loc[:,"Anomaly(1901-2000 Base Period)"] = temp_data_df["Anomaly(1901-2000 Base Period)"].str.replace("°C","")
temp_data_df["Anomaly(1901-2000 Base Period)"] = pd.to_numeric(temp_data_df["Anomaly(1901-2000 Base Period)"])

# %%
temp_data_df["Normalized Temp"]=temp_data_df["Anomaly(1901-2000 Base Period)"]-temp_data_df["Anomaly(1901-2000 Base Period)"].min()

# %%
temp_data_df.head(6)
# Out:
#    Year  Anomaly(1901-2000 Base Period)  Normalized Temp
# 0  1980                            0.29             0.19
# 1  1981                            0.30             0.20
# 2  1982                            0.19             0.09
# 3  1983                            0.33             0.23
# 4  1984                            0.22             0.12
# 5  1985                            0.10             0.00

# %%
# # initiate mongo connection
client = MongoClient()

# %%
db = client['disease_db']

# %%
collection = db.disease_collection

# %%
# make df with latitudes and disease instance information
disease_lat = pd.merge(disease_df, who_and_others[['country', 'latitude']], on='country')
disease_lat.head()
# Out:
#    year   country  disease  instances   latitude
# 0  2011  Cambodia  Malaria    57423.0  12.565679
# 1  2002  Cambodia  Malaria    46902.0  12.565679
# 2  2000  Cambodia  Malaria    62442.0  12.565679
# 3  2009  Cambodia  Malaria    64595.0  12.565679
# 4  2015  Cambodia  Malaria    33930.0  12.565679

# %%
# make dict for JSON format
years = list(temp_data_df['Year'])

# %%
# make dict of one list to upload to mongo
JSON = {
    'data':[]
}
# up to 2016 to match yellow fever data
for year in years[:-2]:
    # initialize dict to add info for each year
    document = {}
    # add temp
    document['temp'] = temp_data_df.loc[
        temp_data_df['Year'] == year, 
        ['Normalized Temp']
    ].values[0][0]
    # add year
    document['year'] = year
    # add disease list, to which disease dicts will be added
    document['disease'] = []
    # iterate over diseases in the dataframe
    for disease in disease_lat['disease'].unique():
        disease_dict = {}
        # check that there is info for a given disease for that year
        if not disease_lat.loc[(disease_lat['disease'] == disease) &
                            (disease_lat['year'] == year) &
                            (disease_lat['instances'] > 2), 
                            :].empty:
            # if there is info, query min and max latitude of spread for that year
            try:
                max_lat = disease_lat.loc[(disease_lat['disease'] == disease) &
                                      (disease_lat['year'] == year) &
                                      (disease_lat['instances'] > 2), 
                                      :]['latitude'].max()
                min_lat = disease_lat.loc[(disease_lat['disease'] == disease) &
                                      (disease_lat['year'] == year) &
                                      (disease_lat['instances'] > 2), 
                                      :]['latitude'].min()
                disease_dict['name'] = disease
                disease_dict['max_lat'] = max_lat
                disease_dict['min_lat'] = min_lat
                # add disease info to list for that year
                document['disease'].append(disease_dict)
            except:
                pass
    # add each year's dictionary to overall list
    JSON['data'].append(document)

# %%
JSON
# Out:
# {'data': [{'temp': 0.18999999999999997,
#    'year': 1980,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.19999999999999998,
#    'year': 1981,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 14.497401000000002,
#      'min_lat': -14.235004}]},
#   {'temp': 0.09,
#    'year': 1982,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 7.946527000000001,
#      'min_lat': -14.235004}]},
#   {'temp': 0.23,
#    'year': 1983,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 12.238333,
#      'min_lat': -14.235004}]},
#   {'temp': 0.12,
#    'year': 1984,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 12.238333,
#      'min_lat': -14.235004}]},
#   {'temp': 0.0,
#    'year': 1985,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 12.238333,
#      'min_lat': -14.235004}]},
#   {'temp': 0.12,
#    'year': 1986,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.22,
#    'year': 1987,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 21.00789,
#      'min_lat': -14.235004}]},
#   {'temp': 0.30000000000000004,
#    'year': 1988,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.18999999999999997,
#    'year': 1989,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.30000000000000004,
#    'year': 1990,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.33999999999999997,
#    'year': 1991,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.19999999999999998,
#    'year': 1992,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.17,
#    'year': 1993,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.18999999999999997,
#    'year': 1994,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.36,
#    'year': 1995,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.30769,
#      'min_lat': -14.235004}]},
#   {'temp': 0.24999999999999997,
#    'year': 1996,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.30769,
#      'min_lat': -14.235004}]},
#   {'temp': 0.33999999999999997,
#    'year': 1997,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.30769,
#      'min_lat': -14.235004}]},
#   {'temp': 0.56,
#    'year': 1998,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.30769,
#      'min_lat': -14.235004}]},
#   {'temp': 0.35,
#    'year': 1999,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 12.238333,
#      'min_lat': -14.235004}]},
#   {'temp': 0.36,
#    'year': 2000,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 9.945587, 'min_lat': -14.235004}]},
#   {'temp': 0.37,
#    'year': 2001,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever',
#      'max_lat': 14.497401000000002,
#      'min_lat': -14.235004}]},
#   {'temp': 0.51,
#    'year': 2002,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 12.238333, 'min_lat': -14.235004}]},
#   {'temp': 0.47,
#    'year': 2003,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 21.00789, 'min_lat': -14.235004}]},
#   {'temp': 0.49,
#    'year': 2004,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 12.238333, 'min_lat': -14.235004}]},
#   {'temp': 0.54,
#    'year': 2005,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 17.570692, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 36.204824, 'min_lat': -38.416097}]},
#   {'temp': 0.51,
#    'year': 2006,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 12.238333, 'min_lat': -9.189967},
#     {'name': 'Leprosy', 'max_lat': 36.204824, 'min_lat': -38.416097}]},
#   {'temp': 0.55,
#    'year': 2007,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 8.619543, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 40.463667, 'min_lat': -38.416097}]},
#   {'temp': 0.41000000000000003,
#    'year': 2008,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 12.238333, 'min_lat': -38.416097},
#     {'name': 'Leprosy', 'max_lat': 40.463667, 'min_lat': -38.416097}]},
#   {'temp': 0.53,
#    'year': 2009,
#    'disease': [{'name': 'Malaria', 'max_lat': 41.20438, 'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 17.570692, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 40.463667, 'min_lat': -38.416097}]},
#   {'temp': 0.6,
#    'year': 2010,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 41.377491,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 17.570692, 'min_lat': -9.189967},
#     {'name': 'Leprosy', 'max_lat': 41.87194, 'min_lat': -40.900557}]},
#   {'temp': 0.49,
#    'year': 2011,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 40.143105,
#      'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 17.607789, 'min_lat': -9.189967},
#     {'name': 'Leprosy', 'max_lat': 35.86166, 'min_lat': -38.416097}]},
#   {'temp': 0.5,
#    'year': 2012,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 40.143105,
#      'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 56.130366, 'min_lat': -9.189967},
#     {'name': 'Leprosy', 'max_lat': 36.204824, 'min_lat': -38.416097}]},
#   {'temp': 0.54,
#    'year': 2013,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 38.861034000000004,
#      'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 15.454166, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 36.204824, 'min_lat': -40.900557}]},
#   {'temp': 0.63,
#    'year': 2014,
#    'disease': [{'name': 'Malaria', 'max_lat': 35.86166, 'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 56.130366, 'min_lat': -9.189967},
#     {'name': 'Leprosy', 'max_lat': 36.204824, 'min_lat': -40.900557}]},
#   {'temp': 0.74,
#    'year': 2015,
#    'disease': [{'name': 'Malaria', 'max_lat': 35.86166, 'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 56.130366, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 40.463667, 'min_lat': -40.900557}]},
#   {'temp': 0.91,
#    'year': 2016,
#    'disease': [{'name': 'Malaria', 'max_lat': 35.86166, 'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 9.945587, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 52.132633, 'min_lat': -38.416097}]}]}

# %%
collection.update({}, JSON, upsert=True)
# Out:
# /anaconda3/envs/classwork/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   """Entry point for launching an IPython kernel.
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}

# %%
collection.find()[0]
# Out:
# {'_id': ObjectId('5ca564b109db5618be288b0c'),
#  'data': [{'temp': 0.18999999999999997,
#    'year': 1980,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.19999999999999998,
#    'year': 1981,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 14.497401000000002,
#      'min_lat': -14.235004}]},
#   {'temp': 0.09,
#    'year': 1982,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 7.946527000000001,
#      'min_lat': -14.235004}]},
#   {'temp': 0.23,
#    'year': 1983,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 12.238333,
#      'min_lat': -14.235004}]},
#   {'temp': 0.12,
#    'year': 1984,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 12.238333,
#      'min_lat': -14.235004}]},
#   {'temp': 0.0,
#    'year': 1985,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 12.238333,
#      'min_lat': -14.235004}]},
#   {'temp': 0.12,
#    'year': 1986,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.22,
#    'year': 1987,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 21.00789,
#      'min_lat': -14.235004}]},
#   {'temp': 0.30000000000000004,
#    'year': 1988,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.18999999999999997,
#    'year': 1989,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.30000000000000004,
#    'year': 1990,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.33999999999999997,
#    'year': 1991,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.19999999999999998,
#    'year': 1992,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.17,
#    'year': 1993,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.18999999999999997,
#    'year': 1994,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.081999,
#      'min_lat': -14.235004}]},
#   {'temp': 0.36,
#    'year': 1995,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.30769,
#      'min_lat': -14.235004}]},
#   {'temp': 0.24999999999999997,
#    'year': 1996,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.30769,
#      'min_lat': -14.235004}]},
#   {'temp': 0.33999999999999997,
#    'year': 1997,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.30769,
#      'min_lat': -14.235004}]},
#   {'temp': 0.56,
#    'year': 1998,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 9.30769,
#      'min_lat': -14.235004}]},
#   {'temp': 0.35,
#    'year': 1999,
#    'disease': [{'name': 'Yellow Fever',
#      'max_lat': 12.238333,
#      'min_lat': -14.235004}]},
#   {'temp': 0.36,
#    'year': 2000,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 9.945587, 'min_lat': -14.235004}]},
#   {'temp': 0.37,
#    'year': 2001,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever',
#      'max_lat': 14.497401000000002,
#      'min_lat': -14.235004}]},
#   {'temp': 0.51,
#    'year': 2002,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 12.238333, 'min_lat': -14.235004}]},
#   {'temp': 0.47,
#    'year': 2003,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 21.00789, 'min_lat': -14.235004}]},
#   {'temp': 0.49,
#    'year': 2004,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 12.238333, 'min_lat': -14.235004}]},
#   {'temp': 0.54,
#    'year': 2005,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 17.570692, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 36.204824, 'min_lat': -38.416097}]},
#   {'temp': 0.51,
#    'year': 2006,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 12.238333, 'min_lat': -9.189967},
#     {'name': 'Leprosy', 'max_lat': 36.204824, 'min_lat': -38.416097}]},
#   {'temp': 0.55,
#    'year': 2007,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 8.619543, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 40.463667, 'min_lat': -38.416097}]},
#   {'temp': 0.41000000000000003,
#    'year': 2008,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 42.315407,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 12.238333, 'min_lat': -38.416097},
#     {'name': 'Leprosy', 'max_lat': 40.463667, 'min_lat': -38.416097}]},
#   {'temp': 0.53,
#    'year': 2009,
#    'disease': [{'name': 'Malaria', 'max_lat': 41.20438, 'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 17.570692, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 40.463667, 'min_lat': -38.416097}]},
#   {'temp': 0.6,
#    'year': 2010,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 41.377491,
#      'min_lat': -38.416097},
#     {'name': 'Yellow Fever', 'max_lat': 17.570692, 'min_lat': -9.189967},
#     {'name': 'Leprosy', 'max_lat': 41.87194, 'min_lat': -40.900557}]},
#   {'temp': 0.49,
#    'year': 2011,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 40.143105,
#      'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 17.607789, 'min_lat': -9.189967},
#     {'name': 'Leprosy', 'max_lat': 35.86166, 'min_lat': -38.416097}]},
#   {'temp': 0.5,
#    'year': 2012,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 40.143105,
#      'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 56.130366, 'min_lat': -9.189967},
#     {'name': 'Leprosy', 'max_lat': 36.204824, 'min_lat': -38.416097}]},
#   {'temp': 0.54,
#    'year': 2013,
#    'disease': [{'name': 'Malaria',
#      'max_lat': 38.861034000000004,
#      'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 15.454166, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 36.204824, 'min_lat': -40.900557}]},
#   {'temp': 0.63,
#    'year': 2014,
#    'disease': [{'name': 'Malaria', 'max_lat': 35.86166, 'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 56.130366, 'min_lat': -9.189967},
#     {'name': 'Leprosy', 'max_lat': 36.204824, 'min_lat': -40.900557}]},
#   {'temp': 0.74,
#    'year': 2015,
#    'disease': [{'name': 'Malaria', 'max_lat': 35.86166, 'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 56.130366, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 40.463667, 'min_lat': -40.900557}]},
#   {'temp': 0.91,
#    'year': 2016,
#    'disease': [{'name': 'Malaria', 'max_lat': 35.86166, 'min_lat': -30.559482},
#     {'name': 'Yellow Fever', 'max_lat': 9.945587, 'min_lat': -14.235004},
#     {'name': 'Leprosy', 'max_lat': 52.132633, 'min_lat': -38.416097}]}]}
