# %%
import requests
import json
from pprint import pprint

# %%
# url="https://www.ncdc.noaa.gov/cdo-web/api/v2/"
url="https://www.ncdc.noaa.gov/cdo-web/api/v2/stations?"
endpoint="datacategoryid=TEMP&"
startdate="1970-10-03"
enddate="2012-09-10"
limit = "limit=1000";
headers = {'token': 'DsynicExNusdhQxSwBceNTAPrSqXqmYU'}

# %%
url_new=url+endpoint+limit
url_new
# Out:
# 'https://www.ncdc.noaa.gov/cdo-web/api/v2/stations?datacategoryid=TEMP&limit=1000'

# %%
x=requests.get(url_new, headers=headers).json()

# %%
pprint(x)
# Out:
# {'metadata': {'resultset': {'count': 48619, 'limit': 1000, 'offset': 1}},
#  'results': [{'datacoverage': 0.5059,
#               'elevation': 249.3,
#               'elevationUnit': 'METERS',
#               'id': 'COOP:010063',
#               'latitude': 34.2553,
#               'longitude': -87.1814,
#               'maxdate': '2015-11-01',
#               'mindate': '1938-01-01',
#               'name': 'ADDISON, AL US'},
#              {'datacoverage': 0.8064,
#               'elevation': 172.2,
#               'elevationUnit': 'METERS',
#               'id': 'COOP:010116',
#               'latitude': 33.17833,
#               'longitude': -86.78167,
#               'maxdate': '2015-11-01',
#               'mindate': '1995-04-01',
#               'name': 'ALABASTER SHELBY CO AIRPORT, AL US'},
#              {'datacoverage': 0.9535,
#               'elevation': 348.1,
#               'elevationUnit': 'METERS',
#               'id': 'COOP:010148',
# ...

# %%
len(x['results'])
# Out:
# 1000

# %%
# abc= x['results'][0]['id']

# %%
id_list=[]
# Empty array to hold the station ids

# %%
abc= x['results']

# %%
for x in range(len(abc)):
    a=abc[x]['id']
    id_list.append(a)

# %%
id_list
# Out:
# ['COOP:010063',
#  'COOP:010116',
#  'COOP:010148',
#  'COOP:010160',
#  'COOP:010163',
#  'COOP:010178',
#  'COOP:010252',
#  'COOP:010260',
#  'COOP:010267',
#  'COOP:010272',
#  'COOP:010338',
#  'COOP:010369',
#  'COOP:010390',
#  'COOP:010395',
#  'COOP:010402',
#  'COOP:010407',
#  'COOP:010422',
#  'COOP:010425',
#  'COOP:010430',
#  'COOP:010505',
#  'COOP:010583',
#  'COOP:010616',
#  'COOP:010655',
#  'COOP:010757',
#  'COOP:010762',
#  'COOP:010764',
#  'COOP:010768',
#  'COOP:010829',
#  'COOP:010831',
#  'COOP:010836',
#  'COOP:011069',
#  'COOP:011080',
#  'COOP:011084',
#  'COOP:011099',
#  'COOP:011189',
#  'COOP:011288',
#  'COOP:011300',
#  'COOP:011301',
#  'COOP:011324',
#  'COOP:011490',
#  'COOP:011512',
#  'COOP:011520',
#  'COOP:011525',
#  'COOP:011566',
#  'COOP:011620',
#  'COOP:011685',
#  'COOP:011694',
#  'COOP:011725',
#  'COOP:011803',
#  'COOP:011940',
#  'COOP:012096',
#  'COOP:012172',
#  'COOP:012188',
#  'COOP:012207',
#  'COOP:012209',
# ...

# %%
yurl="https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:28801&startdate=2010-05-01&enddate=2010-05-01"

# %%
# gather station IDs so you can query the temps from the datasets in next step

y=requests.get(yurl, headers=headers).json()

# %%
pprint (y)
# Out:
# {'metadata': {'resultset': {'count': 8, 'limit': 25, 'offset': 1}},
#  'results': [{'attributes': ',,N,',
#               'datatype': 'PRCP',
#               'date': '2010-05-01T00:00:00',
#               'station': 'GHCND:US1NCBC0005',
#               'value': 0},
#              {'attributes': ',,N,',
#               'datatype': 'SNOW',
#               'date': '2010-05-01T00:00:00',
#               'station': 'GHCND:US1NCBC0005',
#               'value': 0},
#              {'attributes': ',,0,2400',
#               'datatype': 'PRCP',
#               'date': '2010-05-01T00:00:00',
#               'station': 'GHCND:USW00013872',
#               'value': 3},
#              {'attributes': ',,0,',
#               'datatype': 'SNOW',
#               'date': '2010-05-01T00:00:00',
#               'station': 'GHCND:USW00013872',
#               'value': 0},
#              {'attributes': ',,0,',
#               'datatype': 'SNWD',
#               'date': '2010-05-01T00:00:00',
# ...
