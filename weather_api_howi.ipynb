# %%
import requests
import json
from pprint import pprint

# %%
url="https://www.ncdc.noaa.gov/cdo-web/api/v2/"
endpoint="datasets"
headers = {'token': 'WeiEYUgvBTwjIEVxJtsGvzpqMmVGRWSg'}

# %%
url_new=url+endpoint
url_new
# Out:
# 'https://www.ncdc.noaa.gov/cdo-web/api/v2/datasets'

# %%
requests.get(url, headers=headers).json()
# Out:
# [{'path': 'v2/data',
#   'method': 'GET',
#   'parameters': [{'name': 'datasetid', 'required': False},
#    {'name': 'datatypeid', 'required': False},
#    {'name': 'locationid', 'required': False},
#    {'name': 'stationid', 'required': False},
#    {'name': 'startdate', 'required': True},
#    {'name': 'enddate', 'required': True},
#    {'name': 'includemetadata', 'required': False},
#    {'name': 'units', 'required': False},
#    {'name': 'sortfield', 'required': False},
#    {'name': 'sortorder', 'required': False},
#    {'name': 'limit', 'required': False},
#    {'name': 'offset', 'required': False}]},
#  {'path': 'v2/datasets/{id}', 'method': 'GET', 'parameters': []},
#  {'path': 'v2/datasets',
#   'method': 'GET',
#   'parameters': [{'name': 'datatypeid', 'required': False},
#    {'name': 'locationid', 'required': False},
#    {'name': 'stationid', 'required': False},
#    {'name': 'startdate', 'required': False},
#    {'name': 'enddate', 'required': False},
# ...
